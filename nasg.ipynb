# %%
from pymoo.core.problem import ElementwiseProblem
import numpy as np
from pymoo.algorithms.moo.nsga2 import NSGA2
from pymoo.optimize import minimize
from pymoo.core.variable import Choice
from pymoo.operators.sampling.rnd import Sampling
from pymoo.operators.crossover.ux import Crossover
from pymoo.operators.mutation.pm import PolynomialMutation
from pymoo.core.population import Population
from pymoo.core.individual import Individual
from pymoo.termination import get_termination
import random
import random
import re

import json

import matplotlib.pyplot as plt
import numpy as np

POPULATION_SIZE = 100         
GENERATIONS = 100          
MUTATION_RATE = 0.3         
CROSSOVER_RATE = 1       
TOURNAMENT_SIZE = 5   
MAX_REGEX_LENGTH = 100    
MIN_REGEX_LENGTH = 2        
REGEX_CHAR_SET = list("abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789.-_ /:") + \
                 ['\\d', '\\w', '\\s', '.', '*', '+', '?', '^', '$', '|', '(', ')', '[', ']', '{}']


DATA_FILE = 'data.txt'               
MATCHES_FILE = 'matches.txt'         
EVOLVED_OUTPUT_FILE = 'evolved_matches.txt'

# %%
def load_data(filename):
    try:
        with open(filename, 'r', encoding='utf-8') as f:
            lines = set(line.strip() for line in f if line.strip())
        if not lines:
            print(f"Warning: {filename} is empty or contains only whitespace.")
            return []
        print(f"Loaded {len(lines)} unique strings from {filename}.")
        return list(lines)
    except FileNotFoundError:
        print(f"Error: Data file '{filename}' not found.")
        exit(1)

def load_target_definitions(filename):
    targets = []
    try:
        with open(filename, 'r') as f:
            for line_num, line in enumerate(f):
                try:
                    if line.strip():
                        target_def = json.loads(line)
                        if 'name' in target_def and 'matches' in target_def and isinstance(target_def['matches'], list):
                            target_def['matches'] = list(set(str(m) for m in target_def['matches']))
                            targets.append(target_def)
                        else:
                            print(f"Warning: Skipping invalid target definition in {filename} (line {line_num+1}): Missing 'name' or 'matches', or 'matches' is not a list.")
                except json.JSONDecodeError:
                    print(f"Warning: Skipping invalid JSON in {filename} (line {line_num+1}): {line.strip()}")
        if not targets:
            print(f"Warning: No valid target definitions found in {filename}.")
        else:
            print(f"Loaded {len(targets)} target definitions from {filename}.")
        return targets
    except FileNotFoundError:
        print(f"Error: Target definitions file '{filename}' not found.")
        exit(1)

import regex # pip install regex
import concurrent.futures
import time

def calculate_f1_fitness(regex_pattern, true_positive_set, all_data_strings):
    if not regex_pattern:
        return 0.0

    try:
        compiled_regex = regex.compile(regex_pattern)
       
    except regex.error:
        return 0.0
    except Exception as e:
        print(f"Warning: Unexpected error during regex compilation: {e}")
        return 0.0

    fullmatch_positives = set()
    search_positives = set()

    for s in all_data_strings:
        try:
            if compiled_regex.fullmatch(s, timeout=1):
                fullmatch_positives.add(s)
        except TimeoutError:
            print(f"Warning: fullmatch timeout for regex '{regex_pattern}' on string '{s[:50]}...'")
            return 0.0
        except Exception:
            continue

        try:

            if compiled_regex.search(s, timeout=1):
                search_positives.add(s)
        except TimeoutError:
            print(f"Warning: search timeout for regex '{regex_pattern}' on string '{s[:50]}...'")
            return 0.0
        except Exception:
            continue

    def compute_f1(predicted, actual):
        tp = len(predicted & actual)
        if tp == 0:
            return 0.0
        precision = tp / len(predicted) if predicted else 0.0
        recall = tp / len(actual) if actual else 0.0
        return 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0.0

    fullmatch_f1 = compute_f1(fullmatch_positives, true_positive_set)
    search_f1 = compute_f1(search_positives, true_positive_set)

    return fullmatch_f1 + 0.5*search_f1
def curly():
    if random.random() < 0.5:
        r=random.randint(1, 10)
        return f'{{{r}}}'
    else:
        r1 = random.randint(1, 3)
        r2=random.randint(r1, 10)
        return f'{{{r1},{r2}}}'
def generate_initial_population(size, seed_strings, char_set):
    population = []
    attempts = 0
    max_attempts = size * 20

    basics = [r'\w+', r'\d+', r'.*', r'[a-zA-Z]+', r'\d{3,}', r'^\S+$']
    for basic in basics:
        if len(population) < size:
            population.append(basic)
    if seed_strings:
        for _ in range(size // 3): 
            if len(population) < size:
                random_target_str = random.choice(seed_strings)
                if len(random_target_str) > 1:
                    start = random.randint(0, max(0, len(random_target_str) - 2))
                    end = random.randint(start + 1, len(random_target_str))
                    substring = random_target_str[start:end]
                    population.append(re.escape(substring)) 
                elif len(random_target_str) == 1:
                     population.append(re.escape(random_target_str))

    while len(population) < size and attempts < max_attempts:
        length = random.randint(MIN_REGEX_LENGTH, MAX_REGEX_LENGTH // 2)
        pattern_list = []
        current_len = 0
        while current_len < length:
            char = random.choice(char_set)
            if char=='{}':
                char=curly()
            pattern_list.append(char)
            current_len += 1 if '\\' not in char else 2
        pattern = "".join(pattern_list)
        if pattern and pattern.count('[') == pattern.count(']') and \
           pattern.count('(') == pattern.count(')') and \
           pattern.count('{') == pattern.count('}'):
            population.append(pattern)
        attempts += 1

    if len(population) < size and population: 
        print(f"Warning: Could only generate {len(population)} initial individuals. Duplicating...")
        while len(population) < size:
            population.append(random.choice(population))
    elif not population:
        print("Error: Failed to generate any initial individuals. Adding a fallback.")
        population.append(".*") 
        while len(population) < size:
            population.append(".*")


    print(f"Generated initial population of {len(population)} regexes.")
    return population


def tournament_selection(population_with_fitness, k):
    if not population_with_fitness: 
        return ".*" 
    actual_k = min(k, len(population_with_fitness))
    if actual_k == 0:
        return random.choice([item[0] for item in population_with_fitness]) if population_with_fitness else ".*"
    tournament = random.sample(population_with_fitness, actual_k)
    winner = max(tournament, key=lambda item: item[1])
    return winner[0] 


def mutate(regex_pattern, char_set, min_len, max_len):
 
    pattern_list = list(regex_pattern) 
    if not pattern_list and len(regex_pattern) < max_len: 
        return random.choice(char_set)

    mutation_type = random.randint(1, 4)


    if mutation_type == 1 and pattern_list:
        idx = random.randrange(len(pattern_list))
        r=random.choice(char_set)
        if r == '{}':
            r = curly()
        pattern_list[idx] = r


    elif mutation_type == 2 and len(regex_pattern) < max_len:
        idx = random.randrange(len(pattern_list) + 1)
        r=random.choice(char_set)
        if r == '{}':
            r = curly()
        pattern_list.insert(idx, r)


    elif mutation_type == 3 and len(regex_pattern) > min_len and pattern_list:
        idx = random.randrange(len(pattern_list))
        del pattern_list[idx]

    elif mutation_type == 4 and pattern_list:
        action = random.choice(['quantify', 'group', 'nothing'])
        if action == 'quantify' and len(regex_pattern) < max_len -1:
            idx = random.randrange(len(pattern_list))
            quant = random.choice(['*', '+', '?'])
            if pattern_list[idx] not in ['*', '+', '?', '|', '(', ')', '[', ']', '^', '$']:
                 pattern_list.insert(idx + 1, quant)
        elif action == 'group' and len(regex_pattern) < max_len -2 and len(pattern_list) >=1 :
            if len(pattern_list) >= 2:
                start = random.randint(0, len(pattern_list) -2)
                end = random.randint(start+1, len(pattern_list)-1 )
                if end > start :
                    idx_to_group = random.randrange(len(pattern_list))
                    if pattern_list[idx_to_group] not in ['|','^','$']:
                        pattern_list.insert(idx_to_group+1, ')')
                        pattern_list.insert(idx_to_group, '(')


    new_pattern = "".join(pattern_list)
    open_p, close_p = new_pattern.count('('), new_pattern.count(')')
    open_b, close_b = new_pattern.count('['), new_pattern.count(']')
    open_c, close_c = new_pattern.count('{'), new_pattern.count('}')

    if open_p > close_p and len(new_pattern) < max_len: new_pattern += ')' * (open_p - close_p)
    if close_p > open_p : new_pattern = '(' * (close_p - open_p) + new_pattern 
    if open_b > close_b and len(new_pattern) < max_len: new_pattern += ']' * (open_b - close_b)
    if close_b > open_b : new_pattern = '[' * (close_b - open_b) + new_pattern
    if open_c > close_c and len(new_pattern) < max_len: new_pattern += '}' * (open_c - close_c)
    if close_c > open_c : new_pattern = '{' * (close_c - open_c) + new_pattern


    return new_pattern[:max_len]


def crossover(parent1, parent2, max_len):

    choice = random.random()
    child = ""

    if choice < 0.2: 
        child = f"({parent1})|({parent2})"
    elif choice < 0.8 and len(parent1) > 1 and len(parent2) > 1: 
        p1_split = random.randint(1, len(parent1) -1)
        p2_split = random.randint(1, len(parent2) -1)
        child = parent1[:p1_split] + parent2[p2_split:]
    else: 
        child = parent1 + parent2

    if len(child) > max_len:
        child = child[:max_len]
    if not child or len(child) < MIN_REGEX_LENGTH:
        return random.choice([parent1, parent2])

    return child


def save_all_evolved_results(results_list, output_filename):
    try:
        with open(output_filename, 'w', encoding='utf-8') as f:
            for result_dict in results_list:
                json.dump(result_dict, f)
                f.write('\n')
        print(f"\nAll evolved regex results saved to {output_filename}")
    except IOError as e:
        print(f"Error saving results to {output_filename}: {e}")



def run_evolution_for_target(target_name, true_positive_strings_for_target, all_data_strings):
    """Runs the EA for a single target regex."""
    print(f"\n--- Evolving Regex for Target: {target_name} ---")
    print(f"Goal: Match {len(true_positive_strings_for_target)} specific strings (F1 score).")

    seed_data = list(true_positive_strings_for_target) if true_positive_strings_for_target else all_data_strings
    if not seed_data:
        print(f"Warning: No seed data available for target {target_name}. Population might be very random.")
        seed_data = ["sample"]


    population = generate_initial_population(
        POPULATION_SIZE,
        seed_data,
        REGEX_CHAR_SET
    )
    best_overall_regex_for_target = population[0] if population else ".*"
    best_overall_f1_for_target = -1.0
    fitness_scores = [
        calculate_f1_fitness(
            ind,
            true_positive_strings_for_target,
            all_data_strings
        ) for ind in population
    ]
    if fitness_scores:
        initial_best_idx = max(range(len(fitness_scores)), key=fitness_scores.__getitem__)
        if fitness_scores[initial_best_idx] > best_overall_f1_for_target:
            best_overall_f1_for_target = fitness_scores[initial_best_idx]
            best_overall_regex_for_target = population[initial_best_idx]
    for generation in range(GENERATIONS):
        pop_with_fitness = list(zip(population, fitness_scores))
        if fitness_scores: 
            current_best_idx = max(range(len(fitness_scores)), key=fitness_scores.__getitem__)
            current_best_f1 = fitness_scores[current_best_idx]
            current_best_regex = population[current_best_idx]
            if current_best_f1 > best_overall_f1_for_target:
                best_overall_f1_for_target = current_best_f1
                best_overall_regex_for_target = current_best_regex
                print(f"  Gen {generation+1:03d} ({target_name}): New Best F1 = {best_overall_f1_for_target:.4f}, Regex = {best_overall_regex_for_target[:80]}")
            elif (generation + 1) % (GENERATIONS // 10 or 1) == 0: 
                print(f"  Gen {generation+1:03d} ({target_name}): Current Best F1 = {current_best_f1:.4f} (Overall: {best_overall_f1_for_target:.4f})")
        else: 
            print(f"  Gen {generation+1:03d} ({target_name}): Warning - empty fitness scores.")
        new_population = []
        sorted_pop = sorted(pop_with_fitness, key=lambda x: x[1], reverse=True)
        num_elites = 1
        for i in range(min(num_elites, len(sorted_pop))):
            new_population.append(sorted_pop[i][0])
        while len(new_population) < POPULATION_SIZE:
            if not pop_with_fitness : 
                parent1, parent2 = ".*", ".*"
            else:
                parent1 = tournament_selection(pop_with_fitness, TOURNAMENT_SIZE)
                parent2 = tournament_selection(pop_with_fitness, TOURNAMENT_SIZE)

            offspring = ""
            if random.random() < CROSSOVER_RATE and parent1 and parent2:
                offspring = crossover(parent1, parent2, MAX_REGEX_LENGTH)
            else:
                offspring = random.choice([parent1, parent2]) if (parent1 or parent2) else "" 

            if random.random() < MUTATION_RATE and offspring:
                offspring = mutate(offspring, REGEX_CHAR_SET, MIN_REGEX_LENGTH, MAX_REGEX_LENGTH)
            if offspring and len(offspring) >= MIN_REGEX_LENGTH:
                new_population.append(offspring)
            else:
                if pop_with_fitness and random.random() < 0.7:
                     new_population.append(random.choice(sorted_pop[:max(1,POPULATION_SIZE//5)])[0]) 
                else:
                     new_population.append(generate_initial_population(1,seed_data,REGEX_CHAR_SET)[0])

                if len(new_population) >= POPULATION_SIZE: 
                    break
        
        population = new_population[:POPULATION_SIZE]
        if not population: 
            print(f"CRITICAL: Population became empty for target {target_name}. Re-initializing.")
            population = generate_initial_population(POPULATION_SIZE, seed_data, REGEX_CHAR_SET)
        fitness_scores = [
            calculate_f1_fitness(
                ind,
                true_positive_strings_for_target,
                all_data_strings
            ) for ind in population
        ]

    print(f"--- Evolution for {target_name} complete ---")
    print(f"Best regex: {best_overall_regex_for_target}")
    print(f"Best F1 score: {best_overall_f1_for_target:.4f}")
    actual_matches = []
    if best_overall_regex_for_target:
        try:
            compiled_regex = re.compile(best_overall_regex_for_target)
            for s in all_data_strings:
                if compiled_regex.search(s):
                    actual_matches.append(s)
        except re.error:
            print(f"Warning: Best evolved regex for {target_name} is invalid: {best_overall_regex_for_target}")
        except Exception as e:
            print(f"Warning: Error matching with best regex for {target_name}: {e}")
    return {
        'pattern': best_overall_regex_for_target,
        'name': f"evolved_{target_name}",
        'original_target_name': target_name,
        'f1_score': best_overall_f1_for_target,
        'matches': actual_matches,
        'target_true_positives_count': len(true_positive_strings_for_target),
        'evolved_matches_count': len(actual_matches)
    }



def main_evolution_process():
    all_strings_universe = load_data(DATA_FILE)
    if not all_strings_universe:
        print("No strings loaded from data.txt. Cannot proceed.")
        return
    target_definitions = load_target_definitions(MATCHES_FILE)
    if not target_definitions:
        print(f"No target definitions loaded from {MATCHES_FILE}. Cannot proceed.")
        return
    all_evolved_results = []
    for target_def in target_definitions:
        target_name = target_def['name']
      
        true_positive_strings_for_target = set(target_def['matches'])

        evolved_result_for_target = run_nsga2(true_positive_strings_for_target, all_strings_universe).X
        evolved_result_for_target=evolved_result_for_target.flatten()
        evolved_result_for_target=evolved_result_for_target.tolist()
        all_evolved_results.append({target_name: evolved_result_for_target})
    save_all_evolved_results(all_evolved_results, EVOLVED_OUTPUT_FILE)

# %%
class RegexProblem(ElementwiseProblem):
    def __init__(self, true_positive_strings, all_strings):
        super().__init__(n_var=1,
                         n_obj=2,
                         n_constr=0,
                         xl=None,
                         xu=None,
                        )

        self.true_positive_strings = true_positive_strings
        self.all_strings = all_strings

    def _evaluate(self, x, out, *args, **kwargs):
        regex_pattern = x[0]
        f1 = calculate_f1_fitness(regex_pattern, self.true_positive_strings, self.all_strings)

        # Fitness 1: maximize F1 (we'll minimize negative F1)
        f1_score = -f1

        # Fitness 2: minimize regex length
        regex_length = len(regex_pattern)/ MAX_REGEX_LENGTH

        out["F"] = [f1_score, regex_length]

# %%
from pymoo.core.duplicate import ElementwiseDuplicateElimination

class RegexDuplicateElimination(ElementwiseDuplicateElimination):
    def is_equal(self, a, b):
   
        return np.array_equal(a.X, b.X)

class RegexSampling(Sampling):
    def __init__(self, seed_strings, char_set):
        super().__init__()
        self.seed_strings = list(seed_strings)
        self.char_set = char_set

    def _do(self, problem, n_samples, **kwargs):
        pop = generate_initial_population(n_samples, self.seed_strings, self.char_set)
        return np.array([[p] for p in pop], dtype=object)


class RegexMutation(PolynomialMutation):
    def __init__(self):
        super().__init__()

    def _do(self, problem, X, **kwargs):
        mutated = []
        for xi in X:
            mutated_pattern = mutate(xi[0], REGEX_CHAR_SET, MIN_REGEX_LENGTH, MAX_REGEX_LENGTH)
            mutated.append([mutated_pattern])
        return np.array(mutated, dtype=object)


class RegexCrossover(Crossover):
    def __init__(self):
        super().__init__(n_parents=2, n_offsprings=2)

    def _do(self, problem, X, **kwargs):
        n_matings = X.shape[1]
        offspring = np.empty((2, n_matings, 1), dtype=object)

        for i in range(n_matings):
            p1 = X[0, i, 0]
            p2 = X[1, i, 0]

            child1 = crossover(p1, p2, MAX_REGEX_LENGTH)
            child2 = crossover(p2, p1, MAX_REGEX_LENGTH)

            offspring[0, i, 0] = child1
            offspring[1, i, 0] = child2

        return offspring

def run_nsga2(true_positives, all_strings):
    problem = RegexProblem(true_positive_strings=true_positives,
                           all_strings=all_strings)

    algorithm = NSGA2(
        pop_size=POPULATION_SIZE,
        sampling=RegexSampling(true_positives, REGEX_CHAR_SET),
        crossover=RegexCrossover(),
        mutation=RegexMutation(),
        eliminate_duplicates=RegexDuplicateElimination(),
    )

    termination = get_termination("n_gen", GENERATIONS)

    res = minimize(problem,
                   algorithm,
                   termination,
                   seed=1,
                   save_history=True,
                   verbose=True)

    for i, ind in enumerate(res.pop):
        print(f"Solution {i + 1}: Regex = {ind.X[0]}, F1 = {-ind.F[0]:.4f}, Length = {ind.F[1]}")

    return res

# %%
main_evolution_process()
# Out:
# Loaded 9953 unique strings from data.txt.
# Loaded 10 target definitions from matches.txt.
# Generated initial population of 100 regexes.
# ==========================================================
# n_gen  |  n_eval  | n_nds  |      eps      |   indicator
# ==========================================================
#      1 |       98 |      3 |             - |             -
#      2 |      198 |      3 |  0.000000E+00 |             f
#      3 |      298 |      3 |  0.000000E+00 |             f
#      4 |      398 |      3 |  0.000000E+00 |             f
#      5 |      498 |      3 |  0.000000E+00 |             f
#      6 |      598 |      3 |  0.000000E+00 |             f
#      7 |      698 |      4 |  0.0725773184 |             f
#      8 |      798 |      4 |  0.000000E+00 |             f
#      9 |      898 |      4 |  0.000000E+00 |             f
#     10 |      998 |      5 |  0.0794296302 |         ideal
#     11 |     1098 |      5 |  0.000000E+00 |             f
#     12 |     1198 |      6 |  0.000000E+00 |             f
#     13 |     1298 |      7 |  0.000000E+00 |             f
#     14 |     1398 |      9 |  0.1547825793 |         ideal
#     15 |     1498 |      6 |  0.0620896187 |             f
#     16 |     1598 |      6 |  0.000000E+00 |             f
#     17 |     1698 |      8 |  0.0146294196 |             f
#     18 |     1798 |      7 |  0.0033335329 |         ideal
#     19 |     1898 |      8 |  0.0209540021 |             f
#     20 |     1998 |      9 |  0.4398839753 |         ideal
#     21 |     2098 |      9 |  0.000000E+00 |             f
#     22 |     2198 |      9 |  0.000000E+00 |             f
#     23 |     2298 |      9 |  0.000000E+00 |             f
#     24 |     2398 |      9 |  0.1134330736 |         ideal
#     25 |     2498 |      9 |  0.0136460849 |             f
#     26 |     2598 |      9 |  0.9687500000 |         nadir
#     27 |     2698 |      9 |  0.000000E+00 |             f
#     28 |     2798 |      9 |  0.5238095238 |         nadir
#     29 |     2898 |      9 |  0.000000E+00 |             f
#     30 |     2998 |      9 |  0.0052910053 |             f
#     31 |     3098 |      9 |  0.000000E+00 |             f
#     32 |     3198 |      9 |  0.000000E+00 |             f
#     33 |     3298 |     10 |  0.0047619425 |             f
#     34 |     3398 |     10 |  0.000000E+00 |             f
#     35 |     3498 |     11 |  0.000000E+00 |             f
#     36 |     3598 |     10 |  0.2352941176 |         nadir
#     37 |     3698 |     11 |  0.2699808744 |         ideal
#     38 |     3798 |     12 |  0.0045859176 |             f
#     39 |     3898 |     12 |  0.000000E+00 |             f
#     40 |     3998 |     12 |  0.000000E+00 |             f
#     41 |     4098 |     10 |  0.0113205015 |             f
#     42 |     4198 |     10 |  0.000000E+00 |             f
#     43 |     4298 |      7 |  0.0764808989 |         ideal
#     44 |     4398 |      7 |  0.000000E+00 |             f
#     45 |     4498 |      7 |  0.000000E+00 |             f
#     46 |     4598 |      7 |  0.000000E+00 |             f
#     47 |     4698 |      8 |  0.0026832599 |         ideal
#     48 |     4798 |      8 |  0.000000E+00 |             f
#     49 |     4898 |     10 |  0.1179509676 |         nadir
#     50 |     4998 |      8 |  0.0400000000 |         nadir
#     51 |     5098 |      8 |  0.000000E+00 |             f
#     52 |     5198 |      9 |  0.0094003589 |             f
#     53 |     5298 |      9 |  0.000000E+00 |             f
#     54 |     5398 |      9 |  0.000000E+00 |             f
#     55 |     5498 |      9 |  0.000000E+00 |             f
#     56 |     5598 |      9 |  0.000000E+00 |             f
#     57 |     5698 |     10 |  0.000000E+00 |             f
#     58 |     5798 |     10 |  0.000000E+00 |             f
#     59 |     5898 |      9 |  0.0869565217 |         nadir
#     60 |     5998 |      9 |  0.0298507463 |         nadir
#     61 |     6098 |      9 |  0.000000E+00 |             f
#     62 |     6198 |      9 |  0.000000E+00 |             f
#     63 |     6298 |     10 |  0.000000E+00 |             f
#     64 |     6398 |     10 |  0.0307692308 |         nadir
#     65 |     6498 |     10 |  0.000000E+00 |             f
#     66 |     6598 |      9 |  0.0060348254 |             f
#     67 |     6698 |      9 |  0.0422704584 |         ideal
#     68 |     6798 |     10 |  0.000000E+00 |             f
#     69 |     6898 |     10 |  0.000000E+00 |             f
#     70 |     6998 |     11 |  0.000000E+00 |             f
#     71 |     7098 |     11 |  0.000000E+00 |             f
#     72 |     7198 |     10 |  1.0000000000 |         nadir
#     73 |     7298 |     10 |  0.000000E+00 |             f
#     74 |     7398 |     11 |  0.0061664422 |             f
#     75 |     7498 |     10 |  0.0066666667 |             f
#     76 |     7598 |     10 |  0.000000E+00 |             f
#     77 |     7698 |      9 |  0.0334754575 |             f
#     78 |     7798 |      9 |  0.000000E+00 |             f
#     79 |     7898 |     10 |  0.0083265677 |             f
#     80 |     7998 |     10 |  0.000000E+00 |             f
#     81 |     8098 |     10 |  0.1538461538 |         nadir
#     82 |     8198 |     10 |  0.000000E+00 |             f
#     83 |     8298 |     10 |  0.000000E+00 |             f
#     84 |     8398 |     11 |  0.000000E+00 |             f
#     85 |     8498 |     11 |  0.000000E+00 |             f
#     86 |     8598 |     11 |  0.000000E+00 |             f
#     87 |     8698 |     11 |  0.000000E+00 |             f
#     88 |     8798 |     11 |  0.000000E+00 |             f
#     89 |     8898 |     11 |  0.000000E+00 |             f
#     90 |     8998 |     11 |  0.000000E+00 |             f
#     91 |     9098 |     13 |  0.000000E+00 |             f
#     92 |     9198 |     14 |  0.000000E+00 |             f
#     93 |     9298 |     14 |  0.000000E+00 |             f
#     94 |     9398 |     15 |  0.000000E+00 |             f
#     95 |     9498 |     15 |  0.000000E+00 |             f
#     96 |     9598 |     15 |  0.000000E+00 |             f
#     97 |     9698 |     13 |  0.0059171598 |             f
#     98 |     9798 |     11 |  0.0069930070 |             f
#     99 |     9898 |      9 |  0.0833333333 |         nadir
#    100 |     9998 |      9 |  0.000000E+00 |             f
# Solution 1: Regex = .*, F1 = 0.2510, Length = 0.02
# Solution 2: Regex = \S+, F1 = 0.3149, Length = 0.03
# Solution 3: Regex = .+, F1 = 0.2510, Length = 0.02
# Solution 4: Regex = -, F1 = 0.2185, Length = 0.01
# Solution 5: Regex = .-.*, F1 = 0.6166, Length = 0.04
# Solution 6: Regex = \S*, F1 = 0.3149, Length = 0.03
# Solution 7: Regex = ..*-., F1 = 0.8852, Length = 0.05
# Solution 8: Regex = .(.+-\d$()), F1 = 0.9647, Length = 0.11
# Solution 9: Regex = (.*(-(\S$)))+, F1 = 1.0000, Length = 0.13
# Solution 10: Regex = 8, F1 = 0.1303, Length = 0.01
# Solution 11: Regex = \-, F1 = 0.2185, Length = 0.02
# Solution 12: Regex = .-, F1 = 0.2185, Length = 0.02
# Solution 13: Regex = 9..*, F1 = 0.4893, Length = 0.04
# Solution 14: Regex = ^.*, F1 = 0.2510, Length = 0.03
# Solution 15: Regex = ..*, F1 = 0.2510, Length = 0.03
# Solution 16: Regex = ..+, F1 = 0.2510, Length = 0.03
# Solution 17: Regex = .+.-.?, F1 = 0.8852, Length = 0.06
# Solution 18: Regex = .+-.*, F1 = 0.6556, Length = 0.05
# Solution 19: Regex = .*.-.?, F1 = 0.8852, Length = 0.06
# Solution 20: Regex = .*(-(\d$())), F1 = 0.9647, Length = 0.12
# Solution 21: Regex = ((.+-\d$())), F1 = 0.9647, Length = 0.12
# Solution 22: Regex = (.*(-\d$())), F1 = 0.9647, Length = 0.12
# Solution 23: Regex = (((.*-(\S$)))), F1 = 1.0000, Length = 0.14
# Solution 24: Regex = (.*(-(\S$++))), F1 = 1.0000, Length = 0.14
# Solution 25: Regex = ((.*-(\S$++))), F1 = 1.0000, Length = 0.14
# Solution 26: Regex = 7, F1 = 0.1282, Length = 0.01
# Solution 27: Regex = 8-, F1 = 0.2100, Length = 0.02
# Solution 28: Regex = 1-.*, F1 = 0.4424, Length = 0.04
# Solution 29: Regex = \d-, F1 = 0.2309, Length = 0.03
# Solution 30: Regex = .-.+?, F1 = 0.6166, Length = 0.05
# Solution 31: Regex = .+.+-.?, F1 = 0.8852, Length = 0.07
# Solution 32: Regex = (.+.-.), F1 = 0.8852, Length = 0.07
# Solution 33: Regex = ..*-.*, F1 = 0.6556, Length = 0.06
# Solution 34: Regex = \S+-.*, F1 = 0.6556, Length = 0.06
# Solution 35: Regex = ^.*.-.?, F1 = 0.8852, Length = 0.07
# Solution 36: Regex = ^.*.*-., F1 = 0.8852, Length = 0.07
# Solution 37: Regex = (\S*-(\d$())), F1 = 0.9647, Length = 0.13
# Solution 38: Regex = ((.*(-(\S$)()))), F1 = 1.0000, Length = 0.16
# Solution 39: Regex = ((.*(-(\S$)))()), F1 = 1.0000, Length = 0.16
# Solution 40: Regex = (((.*-(\S$))).*), F1 = 1.0000, Length = 0.16
# Solution 41: Regex = (((.*-(\S$)).*)), F1 = 1.0000, Length = 0.16
# Solution 42: Regex = ((.*((-)(\S$)))), F1 = 1.0000, Length = 0.16
# Solution 43: Regex = (((.*(-)(\S$)))), F1 = 1.0000, Length = 0.16
# Solution 44: Regex = 1, F1 = 0.1223, Length = 0.01
# Solution 45: Regex = 1-, F1 = 0.2100, Length = 0.02
# Solution 46: Regex = 1\S+, F1 = 0.3247, Length = 0.04
# Solution 47: Regex = [-], F1 = 0.2185, Length = 0.03
# Solution 48: Regex = (-), F1 = 0.2185, Length = 0.03
# Solution 49: Regex = \S-, F1 = 0.2185, Length = 0.03
# Solution 50: Regex = .\-, F1 = 0.2185, Length = 0.03
# Solution 51: Regex = -.*, F1 = 0.2185, Length = 0.03
# Solution 52: Regex = .*-, F1 = 0.2185, Length = 0.03
# Solution 53: Regex = ..-, F1 = 0.2185, Length = 0.03
# Solution 54: Regex = .+-, F1 = 0.2185, Length = 0.03
# Solution 55: Regex = 1*-, F1 = 0.2185, Length = 0.03
# Solution 56: Regex = .-., F1 = 0.2185, Length = 0.03
# Solution 57: Regex = .-+, F1 = 0.2185, Length = 0.03
# Solution 58: Regex = \S+\d, F1 = 0.3947, Length = 0.05
# Solution 59: Regex = .-.+A?, F1 = 0.6166, Length = 0.06
# Solution 60: Regex = .-.+Q?, F1 = 0.6166, Length = 0.06
# Solution 61: Regex = .-.+-?, F1 = 0.6166, Length = 0.06
# Solution 62: Regex = .?-.+?, F1 = 0.6166, Length = 0.06
# Solution 63: Regex = (.*.-.?), F1 = 0.8852, Length = 0.08
# Solution 64: Regex = .+.-.+?, F1 = 0.6556, Length = 0.07
# Solution 65: Regex = .+-.++$, F1 = 0.6556, Length = 0.07
# Solution 66: Regex = \w.+-.*, F1 = 0.6556, Length = 0.07
# Solution 67: Regex = (.)*(-(\d$())), F1 = 0.9647, Length = 0.14
# Solution 68: Regex = (.*(-\d$()))7*, F1 = 0.9647, Length = 0.14
# Solution 69: Regex = ((.*(-\d$++))), F1 = 0.9647, Length = 0.14
# Solution 70: Regex = ((..*(-(\S$)()))), F1 = 1.0000, Length = 0.17
# Solution 71: Regex = \S+-.*((.+..-.)), F1 = 0.9670, Length = 0.16
# Solution 72: Regex = (.*(-(\S$++)))\S*, F1 = 1.0000, Length = 0.17
# Solution 73: Regex = 6, F1 = 0.0995, Length = 0.01
# Solution 74: Regex = 78, F1 = 0.1847, Length = 0.02
# Solution 75: Regex = \S+$, F1 = 0.3149, Length = 0.04
# Solution 76: Regex = ^\S+, F1 = 0.3149, Length = 0.04
# Solution 77: Regex = \S++, F1 = 0.3149, Length = 0.04
# Solution 78: Regex = 8+-, F1 = 0.2100, Length = 0.03
# Solution 79: Regex = 8\-, F1 = 0.2100, Length = 0.03
# Solution 80: Regex = ^\S+$, F1 = 0.3469, Length = 0.05
# Solution 81: Regex = 9(.).*, F1 = 0.4893, Length = 0.06
# Solution 82: Regex = ((.+.-.)), F1 = 0.8852, Length = 0.09
# Solution 83: Regex = (.+.-(.)), F1 = 0.8852, Length = 0.09
# Solution 84: Regex = .+.+-(.)?, F1 = 0.8852, Length = 0.09
# Solution 85: Regex = (.)+.-.+, F1 = 0.6556, Length = 0.08
# Solution 86: Regex = .*..*-.*, F1 = 0.6556, Length = 0.08
# Solution 87: Regex = (\S*-.*), F1 = 0.6556, Length = 0.08
# Solution 88: Regex = \S+-(.)*, F1 = 0.6556, Length = 0.08
# Solution 89: Regex = (.-\S+), F1 = 0.6166, Length = 0.07
# Solution 90: Regex = .-(\S+), F1 = 0.6166, Length = 0.07
# Solution 91: Regex = (.-.+?), F1 = 0.6166, Length = 0.07
# Solution 92: Regex = .-(.)+?, F1 = 0.6166, Length = 0.07
# Solution 93: Regex = (((.*-(.+-.)))), F1 = 0.8976, Length = 0.15
# Solution 94: Regex = (\S*-.-*.*.-.?), F1 = 0.8976, Length = 0.15
# Solution 95: Regex = (.\S*-(()\d$())), F1 = 0.9647, Length = 0.16
# Solution 96: Regex = (.())*(-(\d$())), F1 = 0.9647, Length = 0.16
# Solution 97: Regex = ((.+-\d$()))(.*), F1 = 0.9647, Length = 0.16
# Solution 98: Regex = (\S*-(\d$(()+))), F1 = 0.9647, Length = 0.16
# Solution 99: Regex = (.*(-(\S$)))|(-)6, F1 = 0.9724, Length = 0.17
# Solution 100: Regex = (.*((.*-(\S$())))), F1 = 1.0000, Length = 0.18
# Generated initial population of 100 regexes.
# ==========================================================
# n_gen  |  n_eval  | n_nds  |      eps      |   indicator
# ==========================================================
#      1 |       97 |      2 |             - |             -
#      2 |      197 |      2 |  0.000000E+00 |             f
#      3 |      297 |      2 |  0.000000E+00 |             f
#      4 |      397 |      2 |  0.000000E+00 |             f
#      5 |      497 |      3 |  0.0246227837 |         ideal
#      6 |      597 |      4 |  0.2989857680 |         ideal
#      7 |      697 |      4 |  0.0237263939 |             f
#      8 |      797 |      4 |  0.000000E+00 |             f
#      9 |      897 |      4 |  0.000000E+00 |             f
#     10 |      997 |      4 |  0.9086573497 |         ideal
#     11 |     1097 |      5 |  0.6562500000 |         nadir
#     12 |     1197 |      5 |  0.000000E+00 |             f
#     13 |     1297 |      6 |  0.0080682174 |         ideal
#     14 |     1397 |      7 |  0.0227320158 |             f
#     15 |     1497 |      8 |  0.0085229732 |             f
#     16 |     1597 |      6 |  0.0227290262 |             f
#     17 |     1697 |      6 |  0.000000E+00 |             f
#     18 |     1797 |      6 |  0.000000E+00 |             f
#     19 |     1897 |      7 |  0.0324692625 |             f
#     20 |     1997 |      9 |  0.0066852908 |         ideal
#     21 |     2097 |     10 |  0.0013515662 |             f
#     22 |     2197 |     11 |  0.0036860235 |             f
#     23 |     2297 |      9 |  0.0017189578 |             f
#     24 |     2397 |     10 |  0.0137076812 |             f
#     25 |     2497 |     10 |  0.000000E+00 |             f
#     26 |     2597 |      9 |  0.0053269471 |         ideal
#     27 |     2697 |      8 |  0.5142857143 |         nadir
#     28 |     2797 |      9 |  0.000000E+00 |             f
#     29 |     2897 |     11 |  0.0086021783 |         ideal
#     30 |     2997 |     11 |  0.0016148544 |             f
#     31 |     3097 |     13 |  0.0041872808 |             f
#     32 |     3197 |     14 |  0.0009437504 |             f
#     33 |     3297 |     12 |  0.0123456790 |         nadir
#     34 |     3397 |     14 |  0.0037297431 |         ideal
#     35 |     3497 |     11 |  0.0184757539 |         ideal
#     36 |     3597 |     12 |  0.0200336444 |         ideal
#     37 |     3697 |     12 |  0.000000E+00 |             f
#     38 |     3797 |     13 |  0.2473118280 |         nadir
#     39 |     3897 |     13 |  0.000000E+00 |             f
#     40 |     3997 |     14 |  0.3098591549 |         nadir
#     41 |     4097 |     14 |  0.000000E+00 |             f
#     42 |     4197 |     14 |  0.0060362349 |             f
#     43 |     4297 |     16 |  0.0025384831 |         ideal
#     44 |     4397 |     16 |  0.0000181183 |             f
#     45 |     4497 |     16 |  0.0000181183 |             f
#     46 |     4597 |     16 |  0.0000181183 |             f
#     47 |     4697 |     17 |  0.0015857401 |             f
#     48 |     4797 |     18 |  0.0014976434 |             f
#     49 |     4897 |     17 |  0.0023553865 |             f
#     50 |     4997 |     15 |  0.0056790389 |             f
#     51 |     5097 |     15 |  0.000000E+00 |             f
#     52 |     5197 |     15 |  0.000000E+00 |             f
#     53 |     5297 |     16 |  0.1935483871 |         nadir
#     54 |     5397 |     17 |  0.0018550766 |             f
#     55 |     5497 |     17 |  0.0312857100 |         nadir
#     56 |     5597 |     20 |  0.0016483802 |             f
#     57 |     5697 |     20 |  0.0016483802 |             f
#     58 |     5797 |     22 |  0.0020025054 |             f
#     59 |     5897 |     22 |  0.0020025054 |             f
#     60 |     5997 |     23 |  0.0062156830 |             f
#     61 |     6097 |     20 |  0.0215053763 |         nadir
#     62 |     6197 |     20 |  0.000000E+00 |             f
#     63 |     6297 |     21 |  0.0076805886 |             f
#     64 |     6397 |     22 |  0.0510204082 |         nadir
#     65 |     6497 |     22 |  0.000000E+00 |             f
#     66 |     6597 |     22 |  0.000000E+00 |             f
#     67 |     6697 |     22 |  0.0009276438 |             f
#     68 |     6797 |     22 |  0.0018552876 |             f
#     69 |     6897 |     22 |  0.0032468201 |             f
#     70 |     6997 |     23 |  0.0038158768 |             f
#     71 |     7097 |     23 |  0.0044499073 |             f
#     72 |     7197 |     23 |  0.0021331672 |             f
#     73 |     7297 |     25 |  0.0023768949 |             f
#     74 |     7397 |     24 |  0.4626865672 |         nadir
#     75 |     7497 |     25 |  0.0011991747 |             f
#     76 |     7597 |     26 |  0.0034466237 |             f
#     77 |     7697 |     27 |  0.0016583763 |             f
#     78 |     7797 |     27 |  0.0016583763 |             f
#     79 |     7897 |     27 |  0.0022122618 |             f
#     80 |     7997 |     29 |  0.2795698925 |         nadir
#     81 |     8097 |     23 |  0.0020494748 |             f
#     82 |     8197 |     23 |  0.0020494748 |             f
#     83 |     8297 |     22 |  0.0026314654 |             f
#     84 |     8397 |     23 |  0.000000E+00 |             f
#     85 |     8497 |     25 |  0.0008606249 |             f
#     86 |     8597 |     27 |  0.0019938719 |             f
#     87 |     8697 |     28 |  0.0026910773 |             f
#     88 |     8797 |     29 |  0.000000E+00 |             f
#     89 |     8897 |     29 |  0.0011188405 |             f
#     90 |     8997 |     24 |  0.0035103423 |             f
#     91 |     9097 |     24 |  0.000000E+00 |             f
#     92 |     9197 |     24 |  0.000000E+00 |             f
#     93 |     9297 |     24 |  0.000000E+00 |             f
#     94 |     9397 |     25 |  0.0008194159 |             f
#     95 |     9497 |     27 |  0.0019535541 |             f
#     96 |     9597 |     27 |  0.0019535541 |             f
#     97 |     9697 |     28 |  0.0022679050 |             f
#     98 |     9797 |     28 |  0.0022679050 |             f
#     99 |     9897 |     29 |  0.0021897013 |             f
#    100 |     9997 |     29 |  0.0021897013 |             f
# Solution 1: Regex = co, F1 = 0.4203, Length = 0.02
# Solution 2: Regex = (co)|(.+om)+, F1 = 1.2533, Length = 0.12
# Solution 3: Regex = (.+)c(.m), F1 = 1.2515, Length = 0.09
# Solution 4: Regex = .(.+om), F1 = 1.2502, Length = 0.07
# Solution 5: Regex = m, F1 = 0.3940, Length = 0.01
# Solution 6: Regex = ((co)|.+om)+, F1 = 1.2533, Length = 0.12
# Solution 7: Regex = .+o, F1 = 0.5017, Length = 0.03
# Solution 8: Regex = (((co|(o(r))))|(((Y)o)|(.+omo)|((((()co+)|(.+()fo)|((.)+)c(.m)))))), F1 = 1.3275, Length = 0.67
# Solution 9: Regex = ((((((((c(o+)|(.+()fo)|((.)n2)|(((()fo8)|((.)..+)c(.m))))))))()))), F1 = 1.3264, Length = 0.66
# Solution 10: Regex = .((()fo)|((.+om)+)), F1 = 1.2733, Length = 0.19
# Solution 11: Regex = ((((co|(o(r))))|((6Y)o)|(.+omo)|((((()co+)|(.+()fo)|((.)+)c(.m)))))), F1 = 1.3280, Length = 0.68
# Solution 12: Regex = (.(.+om+)|co.), F1 = 1.2535, Length = 0.14
# Solution 13: Regex = (.+om), F1 = 1.2500, Length = 0.06
# Solution 14: Regex = (.(..((()fo((6Y)o)|(.+omo)|(((()co+)|(.+()fo)|((.)+)c(.m))))))), F1 = 1.3263, Length = 0.63
# Solution 15: Regex = (((((coFo)|(o*.+c(.m)))+))|(((()fo|(or)))))|(((((((((e*.+)((()fo)|c(.)+b-\s|((c+oA)+)))))))))), F1 = 1.3286, Length = 0.94
# Solution 16: Regex = ((((()co+)|(.+()fo)|(((.)+)c(.m))))), F1 = 1.3261, Length = 0.36
# Solution 17: Regex = (((co|(o(r))))|(((6Y)o|(.+omo)|((((()co+)|(.+()fo)|((.)+)c(.m))))))), F1 = 1.3280, Length = 0.68
# Solution 18: Regex = (((()fo)|^(.)+om)), F1 = 1.2731, Length = 0.18
# Solution 19: Regex = (((co|(o(r))))|(((Y)o)|(.N+om)|((((()co+)|(.+()fo)|(o*.+c(.m))))))), F1 = 1.3275, Length = 0.67
# Solution 20: Regex = ((.(..((()fo((6Y)o)|(.+omo)|(((()co+)|(.+)fo)|((.)+)c(.m))))))), F1 = 1.3263, Length = 0.63
# Solution 21: Regex = (..+om), F1 = 1.2502, Length = 0.07
# Solution 22: Regex = ((((.+om|(.+()fo)|((.)+)c(.m))))), F1 = 1.3228, Length = 0.33
# Solution 23: Regex = (.+..(((())fo)|((.)+om))), F1 = 1.3219, Length = 0.25
# Solution 24: Regex = (o.*m)|((.+om*)m), F1 = 1.2568, Length = 0.17
# Solution 25: Regex = ((((co|(o(r))))|(((6Y)o|(.+omo)|(((()co+)|(.+()fo)|((.)+)c(.m))))))), F1 = 1.3280, Length = 0.68
# Solution 26: Regex = ((..((()fo((6Y)o)|(.+omo)|(((()co+)|(.+()fo)|((.)+)c(.m))))))), F1 = 1.3263, Length = 0.62
# Solution 27: Regex = .(.((()fo)|((.+om)+))), F1 = 1.2737, Length = 0.22
# Solution 28: Regex = (((((co|(o(r))))|(b(6Y)o|(.+omo)|(((()co+)|(.+()fo)|((.)+)c(.m))))))), F1 = 1.3282, Length = 0.69
# Solution 29: Regex = (c(o)|..+o(m)), F1 = 1.2535, Length = 0.14
# Solution 30: Regex = om, F1 = 0.4174, Length = 0.02
# Solution 31: Regex = ((.)+)c(.m), F1 = 1.2515, Length = 0.11
# Solution 32: Regex = (.+)(c)(.m), F1 = 1.2515, Length = 0.11
# Solution 33: Regex = o, F1 = 0.3648, Length = 0.01
# Solution 34: Regex = o.*m, F1 = 0.4459, Length = 0.04
# Solution 35: Regex = .co, F1 = 0.4196, Length = 0.03
# Solution 36: Regex = (.)+o, F1 = 0.5017, Length = 0.05
# Solution 37: Regex = (.((()fo)|((.)+om))), F1 = 1.2733, Length = 0.2
# Solution 38: Regex = .(.+o), F1 = 0.5101, Length = 0.06
# Solution 39: Regex = (((((((()co+)|(.+())fo)|((.)+)c(.m)))))), F1 = 1.3261, Length = 0.4
# Solution 40: Regex = ((((.+()3o+)|(.+(fo)|((.)+)c(.m))))), F1 = 1.3237, Length = 0.36
# Solution 41: Regex = (((((((()co+)|(.+())fo)|((.+)c(.m))))))), F1 = 1.3261, Length = 0.4
# Solution 42: Regex = (((())fo|((.)+om))), F1 = 1.2731, Length = 0.19
# Solution 43: Regex = (((.fo)|((.+om)+))), F1 = 1.2731, Length = 0.19
# Solution 44: Regex = (((co|(o(r))))|(((Y)o)|(.+omo)|((((()3o+)|(.+()fo)|((.)+)c(.m)))))), F1 = 1.3268, Length = 0.67
# Solution 45: Regex = (.(..(((u)fo((6Y)o)|(.+omo)|(((()co+)|(.+()fo)|((.)+)c(.m))))))), F1 = 1.3263, Length = 0.64
# Solution 46: Regex = (.(..((()fo((6Y)o)|(.+omo)|(((()c+o+)|(.+()fo)|((.)+)c(.m))))))), F1 = 1.3263, Length = 0.64
# Solution 47: Regex = .(.+om)+, F1 = 1.2502, Length = 0.08
# Solution 48: Regex = (..+om)+, F1 = 1.2502, Length = 0.08
# Solution 49: Regex = (..+om+), F1 = 1.2502, Length = 0.08
# Solution 50: Regex = (.+om+), F1 = 1.2500, Length = 0.07
# Solution 51: Regex = (.?)+om, F1 = 1.2500, Length = 0.07
# Solution 52: Regex = (((()(f)o)|((.)+om)|(c)o)), F1 = 1.2745, Length = 0.26
# Solution 53: Regex = (((()(f)o)|((.)+om)|(co))), F1 = 1.2745, Length = 0.26
# Solution 54: Regex = (((fo)|((.+om)+)))|((co.)), F1 = 1.2745, Length = 0.26
# Solution 55: Regex = (.+..(((())fo())|((.)+om))), F1 = 1.3219, Length = 0.27
# Solution 56: Regex = (c(o)|(o*.+)c(.m)), F1 = 1.2548, Length = 0.18
# Solution 57: Regex = (co)|((().+)c(.m)), F1 = 1.2548, Length = 0.18
# Solution 58: Regex = (coo)|(o*.+c(.m)), F1 = 1.2535, Length = 0.17
# Solution 59: Regex = (((co|(o(r))))|(((6Y)o|(.+omo)|((((()cq+)|(.+()fo)|((.)+)c(.m))))))), F1 = 1.3273, Length = 0.68
# Solution 60: Regex = (((..((()fo((6Y)o)|W.+omo)|(((()co+)|(.+()fo)|((.)+)c(.m))))))), F1 = 1.3263, Length = 0.63
# Solution 61: Regex = (..(((())fo)|((.)+om))), F1 = 1.2737, Length = 0.23
# Solution 62: Regex = (((co|(o(r))))|(((Y)o)|(.(N)+om)|((((()co+)|(.+()fo)|(o*.+c(.m))))))), F1 = 1.3275, Length = 0.69
# Solution 63: Regex = (((co|(o(r))))|(((Y)o)|(.+(o)mo)|((((()co+)|(.+()fo)|((.)+)c(.m)))))), F1 = 1.3275, Length = 0.69
# Solution 64: Regex = ((((((co|(o(r))))|(b(6Y)o|(.+omo)|(((()co+)|(.+()fo)|((.)+)c(.m)))))))), F1 = 1.3282, Length = 0.71
# Solution 65: Regex = (()co)|(.+om)+, F1 = 1.2533, Length = 0.14
# Solution 66: Regex = (.(.+om+)|co.)+, F1 = 1.2535, Length = 0.15
# Solution 67: Regex = m+, F1 = 0.3940, Length = 0.02
# Solution 68: Regex = ((.+)c(.m+)), F1 = 1.2515, Length = 0.12
# Solution 69: Regex = ((.+)..+om), F1 = 1.2502, Length = 0.11
# Solution 70: Regex = (((.+)c.m+)), F1 = 1.2515, Length = 0.12
# Solution 71: Regex = i, F1 = 0.3036, Length = 0.01
# Solution 72: Regex = (co), F1 = 0.4203, Length = 0.04
# Solution 73: Regex = (c)o, F1 = 0.4203, Length = 0.04
# Solution 74: Regex = com, F1 = 0.4166, Length = 0.03
# Solution 75: Regex = (.*o), F1 = 0.5003, Length = 0.05
# Solution 76: Regex = .((()fo)|(()(.+om)+)), F1 = 1.2733, Length = 0.21
# Solution 77: Regex = (.+o)+, F1 = 0.5017, Length = 0.06
# Solution 78: Regex = ((((.(.+:omo)|(((()co+)|(.+()fo)|((.)+)c(.m))))))), F1 = 1.3261, Length = 0.5
# Solution 79: Regex = ((((()co+)|..+(fo)|(((.))+om)|(c)(.m)))), F1 = 1.3236, Length = 0.4
# Solution 80: Regex = (.)((((((()co+)|(.+()fo)|((.+)c(.m))))))), F1 = 1.3252, Length = 0.41
# Solution 81: Regex = (.)((((((()co+)|(.+())fo)|((.+)c(.m)))))), F1 = 1.3252, Length = 0.41
# Solution 82: Regex = (.(.+om)), F1 = 1.2502, Length = 0.09
# Solution 83: Regex = (o?.*m), F1 = 1.2142, Length = 0.07
# Solution 84: Regex = (.+om*)m, F1 = 1.2500, Length = 0.08
# Solution 85: Regex = (.Z?)+om, F1 = 1.2500, Length = 0.08
# Solution 86: Regex = (.+..(((())fo(()))|((.)+om))), F1 = 1.3219, Length = 0.29
# Solution 87: Regex = (o.*m)|(.((()fo)|((.+om)+))), F1 = 1.2751, Length = 0.28
# Solution 88: Regex = (coo)|(o*.+c(.m)+), F1 = 1.2535, Length = 0.18
# Solution 89: Regex = (...(((())fo)|((.)+om))), F1 = 1.2734, Length = 0.24
# Solution 90: Regex = .(..(((())fo)|((.)+om))), F1 = 1.2734, Length = 0.24
# Solution 91: Regex = ((..(((()())fo)|(.)+om))), F1 = 1.2737, Length = 0.25
# Solution 92: Regex = ((((co|(o(r)))))|(((6Y)o|(.+omo)|((((()cq+)|(.+()fo)|((.)+)c(.m))))))), F1 = 1.3273, Length = 0.7
# Solution 93: Regex = (((((c)o)|(o*.+c((.m)))+))|(((()fo|(or)))))|(((((((((e*.+)((()fo)|c(.)+b-\s|((c+oA)+)))))))))), F1 = 1.3282, Length = 0.94
# Solution 94: Regex = ((((coFo)|(o*.+c(.m))))|(((.(.*(((c(rL4|(.+om)+))|(((()fo))))))))))|((co.))(().+o), F1 = 1.3280, Length = 0.82
# Solution 95: Regex = ((((coFo)|(o*.+c(.m))))|(((.(.*(((c(rL4|(.+om)+))|(((()fo)))))))))|((co.))(().+o)), F1 = 1.3280, Length = 0.82
# Solution 96: Regex = ((((coFo)|(o*.+c+(.m))|(o(r))))|(((6Y)o|(.+omo)|((((()co+)|(.+()fo)|((.)+)c(.m))))))), F1 = 1.3280, Length = 0.85
# Solution 97: Regex = ((((.c+(.m))|(o(r))))|(((6Y)o|(.+omo)|((((()c{3,7}+)|(.+()fo)|((.)+)c(.m))))))), F1 = 1.3277, Length = 0.79
# Solution 98: Regex = (.(.+om+)|((co))), F1 = 1.2535, Length = 0.17
# Solution 99: Regex = (()co+)|(.+om)+, F1 = 1.2533, Length = 0.15
# Solution 100: Regex = (()co+|(.+om)+), F1 = 1.2533, Length = 0.15
# Generated initial population of 100 regexes.
# ==========================================================
# n_gen  |  n_eval  | n_nds  |      eps      |   indicator
# ==========================================================
#      1 |       98 |      4 |             - |             -
#      2 |      198 |      4 |  0.000000E+00 |             f
#      3 |      298 |      4 |  0.000000E+00 |             f
#      4 |      398 |      4 |  0.000000E+00 |             f
#      5 |      498 |      4 |  0.000000E+00 |             f
#      6 |      598 |      4 |  0.000000E+00 |             f
#      7 |      698 |      5 |  0.1459595394 |         ideal
#      8 |      798 |      5 |  0.000000E+00 |             f
#      9 |      898 |      8 |  0.0129083329 |         ideal
#     10 |      998 |      9 |  0.000000E+00 |             f
#     11 |     1098 |      8 |  0.0000833630 |             f
#     12 |     1198 |      8 |  0.0000833630 |             f
#     13 |     1298 |      9 |  0.0026562601 |             f
#     14 |     1398 |     11 |  0.0285807527 |         ideal
#     15 |     1498 |     12 |  0.0010165552 |             f
#     16 |     1598 |     14 |  0.4140763183 |         ideal
#     17 |     1698 |     15 |  0.0109118021 |             f
#     18 |     1798 |     15 |  0.000000E+00 |             f
#     19 |     1898 |     16 |  0.0242725883 |         ideal
#     20 |     1998 |     16 |  0.0708283369 |         ideal
#     21 |     2098 |     17 |  0.0136651990 |         ideal
#     22 |     2198 |     17 |  0.000000E+00 |             f
#     23 |     2298 |     16 |  0.0022499205 |             f
#     24 |     2398 |     12 |  0.0582007464 |         ideal
#     25 |     2498 |     14 |  0.0246524486 |         ideal
#     26 |     2598 |     14 |  0.0002140964 |             f
#     27 |     2698 |     14 |  0.0016718223 |             f
#     28 |     2798 |     14 |  0.0106333611 |             f
#     29 |     2898 |     16 |  0.0118732646 |             f
#     30 |     2998 |     14 |  0.0013178679 |             f
#     31 |     3098 |     14 |  0.0013178679 |             f
#     32 |     3198 |     13 |  0.0093729223 |             f
#     33 |     3298 |     14 |  0.0018249656 |             f
#     34 |     3398 |     14 |  0.0018249656 |             f
#     35 |     3498 |     14 |  0.0019844611 |             f
#     36 |     3598 |     16 |  0.0080406429 |             f
#     37 |     3698 |     17 |  0.0028133543 |             f
#     38 |     3798 |     17 |  0.000000E+00 |             f
#     39 |     3898 |     17 |  0.000000E+00 |             f
#     40 |     3998 |     18 |  0.0048726819 |             f
#     41 |     4098 |     18 |  0.0091663063 |             f
#     42 |     4198 |     19 |  2.887652E-06 |             f
#     43 |     4298 |     20 |  2.743270E-06 |             f
#     44 |     4398 |     20 |  2.743270E-06 |             f
#     45 |     4498 |     20 |  0.0000491510 |             f
#     46 |     4598 |     19 |  0.0005887948 |             f
#     47 |     4698 |     20 |  0.0018312345 |             f
#     48 |     4798 |     20 |  0.0018312345 |             f
#     49 |     4898 |     19 |  0.0165255633 |             f
#     50 |     4998 |     20 |  0.0016296835 |             f
#     51 |     5098 |     21 |  0.0015520795 |             f
#     52 |     5198 |     22 |  0.0014815304 |             f
#     53 |     5298 |     22 |  0.0014815304 |             f
#     54 |     5398 |     23 |  0.0048101072 |             f
#     55 |     5498 |     23 |  0.000000E+00 |             f
#     56 |     5598 |     23 |  0.0004545521 |             f
#     57 |     5698 |     20 |  0.0888888889 |         nadir
#     58 |     5798 |     20 |  0.000000E+00 |             f
#     59 |     5898 |     20 |  0.000000E+00 |             f
#     60 |     5998 |     20 |  0.000000E+00 |             f
#     61 |     6098 |     20 |  0.0055861092 |             f
#     62 |     6198 |     21 |  0.0005291883 |             f
#     63 |     6298 |     21 |  0.0005291883 |             f
#     64 |     6398 |     22 |  0.0032931465 |             f
#     65 |     6498 |     23 |  0.0029039692 |             f
#     66 |     6598 |     22 |  0.0020231367 |             f
#     67 |     6698 |     23 |  0.0112359551 |         nadir
#     68 |     6798 |     23 |  0.0000405194 |             f
#     69 |     6898 |     23 |  0.0000405194 |             f
#     70 |     6998 |     24 |  0.0014651511 |             f
#     71 |     7098 |     24 |  0.0014651511 |             f
#     72 |     7198 |     25 |  0.0113636364 |         nadir
#     73 |     7298 |     25 |  0.000000E+00 |             f
#     74 |     7398 |     25 |  0.0004554983 |             f
#     75 |     7498 |     25 |  0.1282051282 |         nadir
#     76 |     7598 |     25 |  0.0058728670 |             f
#     77 |     7698 |     25 |  0.000000E+00 |             f
#     78 |     7798 |     25 |  0.0000152578 |             f
#     79 |     7898 |     21 |  0.0079585047 |             f
#     80 |     7998 |     21 |  0.000000E+00 |             f
#     81 |     8098 |     21 |  0.0006145148 |             f
#     82 |     8198 |     21 |  0.0006145148 |             f
#     83 |     8298 |     21 |  0.0012250154 |             f
#     84 |     8398 |     21 |  0.0012250154 |             f
#     85 |     8498 |     21 |  0.0012250154 |             f
#     86 |     8598 |     23 |  0.0028005493 |             f
#     87 |     8698 |     22 |  0.0029501374 |             f
#     88 |     8798 |     22 |  0.000000E+00 |             f
#     89 |     8898 |     22 |  0.000000E+00 |             f
#     90 |     8998 |     22 |  0.000000E+00 |             f
#     91 |     9098 |     22 |  0.000000E+00 |             f
#     92 |     9198 |     22 |  0.0000508550 |             f
#     93 |     9298 |     21 |  0.0985915493 |         nadir
#     94 |     9398 |     21 |  0.000000E+00 |             f
#     95 |     9498 |     21 |  0.000000E+00 |             f
#     96 |     9598 |     21 |  0.000000E+00 |             f
#     97 |     9698 |     22 |  0.000000E+00 |             f
#     98 |     9798 |     22 |  0.000000E+00 |             f
#     99 |     9898 |     22 |  0.000000E+00 |             f
#    100 |     9998 |     23 |  0.000000E+00 |             f
# Solution 1: Regex = \d+, F1 = 0.6226, Length = 0.03
# Solution 2: Regex = .*, F1 = 0.2739, Length = 0.02
# Solution 3: Regex = \d{3,}, F1 = 0.6874, Length = 0.06
# Solution 4: Regex = 6, F1 = 0.1613, Length = 0.01
# Solution 5: Regex = .+, F1 = 0.2739, Length = 0.02
# Solution 6: Regex = .\d{3,}, F1 = 0.6916, Length = 0.07
# Solution 7: Regex = \d(\d{3,}$), F1 = 0.7982, Length = 0.11
# Solution 8: Regex = (\d+((\d{3,})|()Y).*(())).\d{3,}, F1 = 1.2625, Length = 0.32
# Solution 9: Regex = (\d{3,}$), F1 = 0.7777, Length = 0.09
# Solution 10: Regex = ((\d((\d{3,})|().Y).*y*))\d\d+., F1 = 1.2212, Length = 0.31
# Solution 11: Regex = (\d+((\d{3,}|()Y).*(())).\d{3,}), F1 = 1.2625, Length = 0.32
# Solution 12: Regex = (((\d+((\d{3})|()Y).*(()).){3,}$)), F1 = 1.4770, Length = 0.34
# Solution 13: Regex = ((\d((\d{3,})|m().Y).\d(.+\d\d{3,}$))), F1 = 1.4824, Length = 0.38
# Solution 14: Regex = .\d+, F1 = 0.6233, Length = 0.04
# Solution 15: Regex = (((\d((\d{3}).*\d+)))), F1 = 1.1187, Length = 0.22
# Solution 16: Regex = (\d(.+\d\d{3}$)), F1 = 0.8628, Length = 0.16
# Solution 17: Regex = \d+.((\d{3,})|().Y).*.+(\d{3,}?)., F1 = 1.3092, Length = 0.33
# Solution 18: Regex = (((\d+(.)((\d{3,})|().Y).*\d{3,}.\d{3,}$))), F1 = 1.4960, Length = 0.43
# Solution 19: Regex = ((\d(\d.*(())\d))\d+.(\d{3,})|()(.)Y).u*((:1(9)6(\d2894)|\d{3,}$)).*, F1 = 1.4985, Length = 0.68
# Solution 20: Regex = (((\d+((\d{3}).*((\d(\d{3}|()(uY).*\-+))))(())).))\d+((.\d\d{3,}$)\d*()), F1 = 1.5000, Length = 0.72
# Solution 21: Regex = ((\d(.*\d))\d+.(\d{3,})|()(.)Y).u*((:1(9)6(\d2894)|\d{3,}$)).*, F1 = 1.4970, Length = 0.62
# Solution 22: Regex = ((((\d+((\d{3}).*((\d(\d{3}|()(uY).*\-+))))())).))\d+((.\d\d{3,}$)\d*()), F1 = 1.5000, Length = 0.72
# Solution 23: Regex = ((\d(.*\d))\d+.(\d{3,})|()(.)Y).u*((:1(G)6(\d2894)|\d{3,}$)).*, F1 = 1.4970, Length = 0.62
# Solution 24: Regex = \d*, F1 = 0.6054, Length = 0.03
# Solution 25: Regex = 5, F1 = 0.1581, Length = 0.01
# Solution 26: Regex = 6., F1 = 0.1618, Length = 0.02
# Solution 27: Regex = .u*\d+., F1 = 0.6243, Length = 0.07
# Solution 28: Regex = (\d+$()), F1 = 0.6888, Length = 0.08
# Solution 29: Regex = 7?\d(\d{3,}$), F1 = 0.7982, Length = 0.13
# Solution 30: Regex = (\d(\d{3,}$)), F1 = 0.7982, Length = 0.13
# Solution 31: Regex = \d+.(($)), F1 = 0.7350, Length = 0.09
# Solution 32: Regex = .(\d{3,}$), F1 = 0.7777, Length = 0.1
# Solution 33: Regex = ((\d((\d{3,})|().O).*y*))\d\d+., F1 = 1.2210, Length = 0.31
# Solution 34: Regex = ((\d((\d{3,})|()b.Y).*y*))\d\d+., F1 = 1.2213, Length = 0.32
# Solution 35: Regex = (((\d(\d{3,})|()b.Y).*y*))\d\d+., F1 = 1.2213, Length = 0.32
# Solution 36: Regex = \w+((\d+(.)((\d).\d(.+\d\d{3,}$)))), F1 = 1.4474, Length = 0.35
# Solution 37: Regex = (((\d(\d{3})|()Y).*y*))((\d{3,}$)), F1 = 1.3671, Length = 0.34
# Solution 38: Regex = (((\d+((\d{3})|()Y).*(()).){3,}))\d*, F1 = 1.4770, Length = 0.36
# Solution 39: Regex = (((\d+((\d{3})|()Y).*(()).){3,}))\d*(\d)+, F1 = 1.4792, Length = 0.41
# Solution 40: Regex = \d+., F1 = 0.6228, Length = 0.04
# Solution 41: Regex = \d+.((\d{3,})|().Y).*., F1 = 0.8975, Length = 0.22
# Solution 42: Regex = (((\d(\d{3})|()Y).*y*)), F1 = 1.0236, Length = 0.23
# Solution 43: Regex = 4*(((\d((\d{3}).*\d+)))), F1 = 1.1187, Length = 0.24
# Solution 44: Regex = (\d(.+\d\d{3,}$)), F1 = 0.8628, Length = 0.17
# Solution 45: Regex = ((..*\d\d{3,}$)), F1 = 0.8523, Length = 0.16
# Solution 46: Regex = (((\d+(.)((\d{3,})|().Y).*\d{3,}.\d{3,}$))(\d*)), F1 = 1.4960, Length = 0.48
# Solution 47: Regex = (((((\d(\d{3,})|5()b.Y).*((\d(\d{3}|()(uY).*\d+))))(())).))\d+((.\d\d{3,}$)\d*), F1 = 1.5000, Length = 0.79
# Solution 48: Regex = (((((\d(\d{3,})|5()b.Y).*((\d(\d{3}|()(uY).*\-+))))(())).))\d+((.\d\d{3,}$)\d*), F1 = 1.5000, Length = 0.79
# Solution 49: Regex = (((\d((\d{3})((..*\d))\d+.(\d{3,})|()(.)Y).u*((:1(9)6(\d2894)|\d{3,}$)).*))), F1 = 1.4995, Length = 0.76
# Solution 50: Regex = ((((((\d(\d{3,})|5()b.Y).*(\d(\d{3}|()(uY).*\d+))))(())).))\d+((.\d\d{3,}$)\d*), F1 = 1.5000, Length = 0.79
# Solution 51: Regex = (\d((()|()Y).*\d))\d+.((\d{3,})|()(.)Y).u*((:1(9)(0\d2894)|\d{3,}$)), F1 = 1.4970, Length = 0.68
# Solution 52: Regex = \w+, F1 = 0.3863, Length = 0.03
# Solution 53: Regex = \w*, F1 = 0.3863, Length = 0.03
# Solution 54: Regex = 3, F1 = 0.1580, Length = 0.01
# Solution 55: Regex = 6+, F1 = 0.1613, Length = 0.02
# Solution 56: Regex = (\d{3,}), F1 = 0.6874, Length = 0.08
# Solution 57: Regex = ((.*\d{3,}$)), F1 = 0.7907, Length = 0.13
# Solution 58: Regex = ((.\d\d{3,}$)), F1 = 0.7982, Length = 0.14
# Solution 59: Regex = (\d{3,}?)., F1 = 0.6907, Length = 0.1
# Solution 60: Regex = ((\d{3,}$)), F1 = 0.7777, Length = 0.11
# Solution 61: Regex = 4*(((\d((\d{3}.*\d.*y*))\d+.))), F1 = 1.2034, Length = 0.31
# Solution 62: Regex = (((\d(\d{3,})|5()b.Y).*y*))\d\d+., F1 = 1.2213, Length = 0.33
# Solution 63: Regex = (((\d(\d{3,}|5()b.Y).*y*))\d\d+.), F1 = 1.2213, Length = 0.33
# Solution 64: Regex = ((((\d((\d{3})|().Y).*y*)))).\d{3,}, F1 = 1.2625, Length = 0.35
# Solution 65: Regex = (((\d+(.)((\d{3,})|().Y).*\d{3,}$))), F1 = 1.4631, Length = 0.36
# Solution 66: Regex = (((\d((\d{3}).*\d+))))(\d(.+\d\d{3,}$)), F1 = 1.4712, Length = 0.39
# Solution 67: Regex = ((\d((\d{3,})|().Y).*y*))\d\d+.(\d+(\d.$))+, F1 = 1.4787, Length = 0.43
# Solution 68: Regex = \d+6?, F1 = 0.6226, Length = 0.05
# Solution 69: Regex = 7?\d+., F1 = 0.6228, Length = 0.06
# Solution 70: Regex = (\d)+, F1 = 0.6226, Length = 0.05
# Solution 71: Regex = .+\d, F1 = 0.4586, Length = 0.04
# Solution 72: Regex = \d+.(), F1 = 0.6228, Length = 0.06
# Solution 73: Regex = (((\d(\d{3}|()uY).*y*))), F1 = 1.0425, Length = 0.24
# Solution 74: Regex = (((\d(\d{3}|()(u)Y).*\d+))), F1 = 1.1187, Length = 0.27
# Solution 75: Regex = (((\d(\d{3}|()()Y).*\d+))), F1 = 1.1157, Length = 0.26
# Solution 76: Regex = (((..*\d))\d+.(\d{3,})|()(.)Y).u*((:1(9)6(\d2894)|\d{3,}$)).*, F1 = 1.4955, Length = 0.61
# Solution 77: Regex = ((((\d((\d{3})|().Y).*y*)))).\d{3,}((.\d\d{3,}$)), F1 = 1.4921, Length = 0.49
# Solution 78: Regex = (((((\d((\d{3})|().Y).*y*)))).\d{3,}(.\d\d{3,}$)), F1 = 1.4921, Length = 0.49
# Solution 79: Regex = (((\d+(.)((\d{3,})|().Y).*\d(\d{3,})|()(.)Y).u*((:1(9)6(\d2894)a|\d{3,}$)))), F1 = 1.4975, Length = 0.76
# Solution 80: Regex = .*(((((\d(\d{3})|5()b.Y).*((\d(\d{3}|()(uY).*\d+))))(())).))\d+((.\d\d{3,}$)\d*), F1 = 1.5000, Length = 0.8
# Solution 81: Regex = ((\d((\d(((()()|()Y).*\d))\d+.((\d{3,})|()(.)Y).u*((:1()6(\d2894)|\d{3,}$)))))), F1 = 1.4985, Length = 0.79
# Solution 82: Regex = (\d((()|()Y).*\d))\d+.((\d{3,})|()(.)Y).u*((a:1(9)(0\d2894)|\d{3,}$)), F1 = 1.4970, Length = 0.69
# Solution 83: Regex = ((((((\d(\d{3,})|().Y)j*y*).*((\d(\d{3}|()(uY).*\-+))))(())).))\d+((.\d\d{3,}$)\d*), F1 = 1.5000, Length = 0.83
# Solution 84: Regex = 4, F1 = 0.1530, Length = 0.01
# Solution 85: Regex = ((((\d((()|()Y{3,})|5()b.Y).*((\d(\d{3}|()(uY)7*\-+))))(())).))\d+((.\d\d{3,}$)\d*), F1 = 1.5000, Length = 0.83
# Solution 86: Regex = (((\d(\d{3})|()uY).*y*)), F1 = 1.0424, Length = 0.24
# Solution 87: Regex = 7?\d(\d{3,}$()), F1 = 0.7982, Length = 0.15
# Solution 88: Regex = (\d*), F1 = 0.6054, Length = 0.05
# Solution 89: Regex = (\d(\d.*(()(\d(\d{3}|()(uY2*\d+))))((.\d{3,}$)))), F1 = 1.4901, Length = 0.49
# Solution 90: Regex = \w*+, F1 = 0.3863, Length = 0.04
# Solution 91: Regex = (((\d(\d{3}|()uY).*y*)()))\d+, F1 = 1.1187, Length = 0.29
# Solution 92: Regex = ((\d((\d{3,})|().O).*y*()))\d\d+., F1 = 1.2210, Length = 0.33
# Solution 93: Regex = 6.*, F1 = 0.3111, Length = 0.03
# Solution 94: Regex = (((\d+((\d{3}).*\d+))))(\d(.+\d\d{3,}$)), F1 = 1.4712, Length = 0.4
# Solution 95: Regex = \d*\d+.((\d{3,})|().Y).*.+(\d{3,}?)., F1 = 1.3092, Length = 0.36
# Solution 96: Regex = ((\d((\d{3})|().Y).*p*))7?\d(\d{3,}$), F1 = 1.4054, Length = 0.37
# Solution 97: Regex = (\d{3,}?), F1 = 0.6874, Length = 0.09
# Solution 98: Regex = (\d+(\d.))+, F1 = 0.7203, Length = 0.11
# Solution 99: Regex = (((\d(\d{3,})|5()bY).*((\d(\d{3}|()(uY).*\d+))))((.\d{3,}$))), F1 = 1.4945, Length = 0.61
# Solution 100: Regex = (((\d+(.)((\d{3,})|().Y).*\d(\d{3,})|()(.)Y).P*((:1(9)6(\d2894)a|94)|\d{3,}$))), F1 = 1.4975, Length = 0.79
# Generated initial population of 100 regexes.
# ==========================================================
# n_gen  |  n_eval  | n_nds  |      eps      |   indicator
# ==========================================================
#      1 |       99 |      2 |             - |             -
#      2 |      199 |      2 |  0.000000E+00 |             f
#      3 |      299 |      2 |  0.000000E+00 |             f
#      4 |      399 |      3 |  0.7326980101 |         ideal
#      5 |      499 |      4 |  0.2567076937 |         ideal
#      6 |      599 |      6 |  0.5956899500 |         ideal
#      7 |      699 |      6 |  0.3482465759 |         ideal
#      8 |      799 |      5 |  0.0042369749 |         ideal
#      9 |      899 |      6 |  0.1415732926 |         ideal
#     10 |      999 |      7 |  0.1426724285 |         ideal
#     11 |     1099 |      7 |  0.000000E+00 |             f
#     12 |     1199 |      8 |  0.0228668354 |         ideal
#     13 |     1299 |     10 |  0.0486361240 |             f
#     14 |     1399 |     10 |  0.1540220100 |         ideal
#     15 |     1499 |     10 |  0.000000E+00 |             f
#     16 |     1599 |     11 |  0.0770768997 |         ideal
#     17 |     1699 |     11 |  0.0443481427 |             f
#     18 |     1799 |     11 |  0.0157978642 |             f
#     19 |     1899 |     10 |  0.1532697403 |         ideal
#     20 |     1999 |     10 |  0.0073170732 |             f
#     21 |     2099 |     12 |  0.0156487656 |             f
#     22 |     2199 |     13 |  0.0124640754 |             f
#     23 |     2299 |     13 |  0.000000E+00 |             f
#     24 |     2399 |     15 |  0.0120731077 |             f
#     25 |     2499 |     16 |  0.0038384635 |             f
#     26 |     2599 |     16 |  0.0008894988 |             f
#     27 |     2699 |     18 |  0.0106032654 |             f
#     28 |     2799 |     18 |  0.0012465706 |             f
#     29 |     2899 |     19 |  0.0041238746 |             f
#     30 |     2999 |     19 |  0.000000E+00 |             f
#     31 |     3099 |     21 |  0.0067441858 |             f
#     32 |     3199 |     22 |  0.0005944932 |             f
#     33 |     3299 |     22 |  0.0061494699 |             f
#     34 |     3399 |     24 |  0.0010197708 |             f
#     35 |     3499 |     24 |  0.0010197708 |             f
#     36 |     3599 |     25 |  0.0028240786 |             f
#     37 |     3699 |     26 |  0.0014094198 |             f
#     38 |     3799 |     27 |  0.0032325689 |             f
#     39 |     3899 |     19 |  0.0069977103 |             f
#     40 |     3999 |     19 |  0.0025673941 |             f
#     41 |     4099 |     16 |  0.0053775106 |         ideal
#     42 |     4199 |     13 |  0.3857142857 |         nadir
#     43 |     4299 |     13 |  0.0071443923 |         ideal
#     44 |     4399 |     13 |  0.000000E+00 |             f
#     45 |     4499 |     13 |  0.000000E+00 |             f
#     46 |     4599 |     13 |  0.0011932830 |             f
#     47 |     4699 |     14 |  0.0055500137 |             f
#     48 |     4799 |     14 |  0.000000E+00 |             f
#     49 |     4899 |     15 |  0.0030782258 |             f
#     50 |     4999 |     13 |  0.0051549752 |             f
#     51 |     5099 |     15 |  0.0073683232 |             f
#     52 |     5199 |     15 |  0.000000E+00 |             f
#     53 |     5299 |     14 |  0.0156250000 |         nadir
#     54 |     5399 |     12 |  0.0117775977 |             f
#     55 |     5499 |     12 |  0.0105008972 |             f
#     56 |     5599 |     13 |  0.1351351351 |         nadir
#     57 |     5699 |     14 |  0.000000E+00 |             f
#     58 |     5799 |     14 |  0.000000E+00 |             f
#     59 |     5899 |     15 |  0.0878424982 |         ideal
#     60 |     5999 |     16 |  0.0026041841 |             f
#     61 |     6099 |     15 |  0.0029334980 |             f
#     62 |     6199 |     16 |  0.1724137931 |         nadir
#     63 |     6299 |     18 |  0.0035428322 |         ideal
#     64 |     6399 |     19 |  0.0016986224 |             f
#     65 |     6499 |     19 |  0.0039624124 |             f
#     66 |     6599 |     19 |  0.000000E+00 |             f
#     67 |     6699 |     19 |  0.000000E+00 |             f
#     68 |     6799 |     21 |  0.0108695652 |         nadir
#     69 |     6899 |     21 |  0.000000E+00 |             f
#     70 |     6999 |     21 |  0.000000E+00 |             f
#     71 |     7099 |     24 |  0.0612244898 |         nadir
#     72 |     7199 |     25 |  0.0012331046 |             f
#     73 |     7299 |     26 |  0.0819175317 |         ideal
#     74 |     7399 |     28 |  0.0007290146 |             f
#     75 |     7499 |     28 |  0.0007290146 |             f
#     76 |     7599 |     28 |  0.0007290146 |             f
#     77 |     7699 |     28 |  0.0035785644 |             f
#     78 |     7799 |     30 |  0.0101010101 |         nadir
#     79 |     7899 |     26 |  0.0031302813 |             f
#     80 |     7999 |     25 |  0.0008081500 |             f
#     81 |     8099 |     27 |  0.0011233461 |             f
#     82 |     8199 |     28 |  0.0014484855 |             f
#     83 |     8299 |     29 |  0.0013985377 |             f
#     84 |     8399 |     28 |  0.0015277213 |             f
#     85 |     8499 |     31 |  0.0041714638 |             f
#     86 |     8599 |     31 |  0.0175657934 |         ideal
#     87 |     8699 |     31 |  0.000000E+00 |             f
#     88 |     8799 |     33 |  0.0024825905 |             f
#     89 |     8899 |     30 |  0.0045601722 |         ideal
#     90 |     8999 |     30 |  0.000000E+00 |             f
#     91 |     9099 |     31 |  0.000000E+00 |             f
#     92 |     9199 |     31 |  0.0003750938 |             f
#     93 |     9299 |     29 |  0.0257226734 |         ideal
#     94 |     9399 |     29 |  0.000000E+00 |             f
#     95 |     9499 |     29 |  0.0012719830 |             f
#     96 |     9599 |     29 |  0.0012719830 |             f
#     97 |     9699 |     30 |  0.0012295836 |             f
#     98 |     9799 |     31 |  0.0026605198 |             f
#     99 |     9899 |     31 |  0.000000E+00 |             f
#    100 |     9999 |     24 |  0.0024892329 |             f
# Solution 1: Regex = .*, F1 = 0.2682, Length = 0.02
# Solution 2: Regex = n, F1 = 0.2499, Length = 0.01
# Solution 3: Regex = .*n, F1 = 0.5987, Length = 0.03
# Solution 4: Regex = ..*n, F1 = 0.6001, Length = 0.04
# Solution 5: Regex = (((((.*.s)))|(.*([ S].*e)|(.(.)*)n)))|(..*er), F1 = 0.9931, Length = 0.45
# Solution 6: Regex = (((.*.s))|(.*n))|(i).*(e), F1 = 0.8552, Length = 0.25
# Solution 7: Regex = (((.*.s)$)|(.*n))|(i), F1 = 0.8526, Length = 0.21
# Solution 8: Regex = ((((.*.s)|(.*\s)(((.*)n(.*))))|(((.*e[z S])|(.*n))))), F1 = 1.0043, Length = 0.53
# Solution 9: Regex = (((.?.*.s)))|(()((.*e[az S])|(.*n)))|(.*r), F1 = 0.9873, Length = 0.42
# Solution 10: Regex = (((Wi|(.*\s)(((.*)n(.*)))))), F1 = 0.8724, Length = 0.28
# Solution 11: Regex = .*r|(.*n), F1 = 0.7381, Length = 0.09
# Solution 12: Regex = ((((.*.s)|(.*\s)(((.*)n(.*))))|(((r))))), F1 = 0.9842, Length = 0.4
# Solution 13: Regex = ((..*.s))|(.*n)|(i), F1 = 0.8492, Length = 0.19
# Solution 14: Regex = (((.*.s)$)|(.*n)|(i)), F1 = 0.8526, Length = 0.21
# Solution 15: Regex = ((((.*.s))|(.*n))|(i).*e), F1 = 0.8552, Length = 0.25
# Solution 16: Regex = (((Ti|(.*\s)(((.*)n(.*))))|..*er)), F1 = 0.9449, Length = 0.34
# Solution 17: Regex = (((((.*.s)|(.*\s)(((.*)n(.*))))|(((r))))))|(.*r|(.*n)), F1 = 1.0238, Length = 0.54
# Solution 18: Regex = (((((.*.s)|(.*\s)(((.*)n(.*)))|(((r))))))|(.*r|(.*n))), F1 = 1.0238, Length = 0.54
# Solution 19: Regex = ((i|(.*\s)((.*)n(n)|(((.?.*s)))|(((.*e[az+ S])|(.*n)))|(.*r)))), F1 = 1.0615, Length = 0.63
# Solution 20: Regex = ((((.*)n*\s)((.*)n(n)|(((.?.*.s)))|(((.*e[azd+ S])|(.*n)))|(.*r)))), F1 = 1.1962, Length = 0.67
# Solution 21: Regex = ((((.*.s)|(.*\s)(((.*)n(.*))))|(((.*e[z $])|(.*n.*er))))), F1 = 1.0460, Length = 0.57
# ...
# Solution 51: Regex = ((((((E(().*))|((((N:(K*E)*W)|(.*)B).*))|(W)|(YE))))|(.*L))|(S.*)).*, F1 = 0.8277, Length = 0.68
# Solution 52: Regex = ((((((((L.+|(.*()E+)|L.+|(^*W)|(.*)B).*)|(W)|(YE)))))))|((S.*)|(L.*)), F1 = 0.8389, Length = 0.69
# Solution 53: Regex = ((E.*)|((L.+|(.*)B)(.+)?))|((S.*())|T()), F1 = 0.7519, Length = 0.4
# Solution 54: Regex = ((E.*)|(L.+|(.*(()))B.*))|((S.*)|(B.*)), F1 = 0.7477, Length = 0.39
# Solution 55: Regex = (L.+|(.*)B)(.+)?, F1 = 0.5698, Length = 0.16
# Solution 56: Regex = ((B.+|H)), F1 = 0.3734, Length = 0.09
# Solution 57: Regex = B((.*)), F1 = 0.3414, Length = 0.07
# Solution 58: Regex = ((B.*)), F1 = 0.3414, Length = 0.07
# Solution 59: Regex = ((.*E.*)|), F1 = 0.4122, Length = 0.1
# Solution 60: Regex = ((((((L.+|(.*()E+)|((W.*)*)B).*))|(W)|(Y))))|(.*T), F1 = 0.7626, Length = 0.5
# Solution 61: Regex = (((E.*)|(L.+|(.*(()))U.*))|((S.+)))|((S.*)|(B.*)), F1 = 0.7526, Length = 0.49
# Solution 62: Regex = (((E.*)|(L.+|(.*(())U.*))|((S.+)))|((S.*)|(B.*))), F1 = 0.7526, Length = 0.49
# Solution 63: Regex = (S.*)|(B.*), F1 = 0.5193, Length = 0.11
# Solution 64: Regex = (E.*)|((L.+|(.*)B)(.+)?), F1 = 0.6830, Length = 0.24
# Solution 65: Regex = S.*, F1 = 0.3140, Length = 0.03
# Solution 66: Regex = (S.*)|((L|(.*)B(.*))), F1 = 0.6130, Length = 0.21
# Solution 67: Regex = ((((LZ+|(.*)\d)\s.*))), F1 = 0.6711, Length = 0.22
# Solution 68: Regex = (L.*+|(.*B.*)|(W.)), F1 = 0.6113, Length = 0.19
# Solution 69: Regex = (W)|((L.+|(.*((((((L.*+|(.*()E+)|LH-+|(^M*W)|(P*)B).*)))))))), F1 = 0.8200, Length = 0.61
# Solution 70: Regex = W, F1 = 0.1475, Length = 0.01
# Solution 71: Regex = ((((((((().*))L|(W))|(Y))|(.*)B).*))), F1 = 0.7398, Length = 0.37
# Solution 72: Regex = (E.*)|(((((\w((.*)\d)\s.*))))|(R)), F1 = 0.7370, Length = 0.34
# Solution 73: Regex = (B.*)|(((((\w((.*)\d)\s.*))))|C(R)), F1 = 0.7395, Length = 0.35
# Solution 74: Regex = ( aL.+|(.*((((((L.+|(.*()E+)|L.-+|(^M*W)|(P*)B).*))))))), F1 = 0.8047, Length = 0.56
# Solution 75: Regex = (((((((((L.+|(.*()E+)|L.-+|^M*W)|(.*)B).*))|(W.*)))))), F1 = 0.8028, Length = 0.54
# Solution 76: Regex = (((((((L.+|(.*()E+)|L.+|(^M*W)|(.*)B).*)|(W)|(YE)))))), F1 = 0.8028, Length = 0.54
# Solution 77: Regex = ((S.*)|(B.))|(((((((((().*))L|(W))|(Y))|(.*)B).*)))), F1 = 0.7804, Length = 0.52
# Solution 78: Regex = (.*(E.*)|((L.+|(.*a)B)(.+)?))|(.*(((((((L.+|(^M*W)|(.*)B).*))|(W)|(YN))))|(.*L))|(S.*)), F1 = 0.8458, Length = 0.87
# Solution 79: Regex = E((L.*)|(E.))|(((((((.*(E(().*))|(((()L.+.+|(^M*W)|(.*)B).*))|(W)|(YN))))|(.*L))|(S.*)))), F1 = 0.8485, Length = 0.89
# Solution 80: Regex = (((((.*))\s+|(.*)(BK)).*)), F1 = 0.6965, Length = 0.26
# Solution 81: Regex = .*(E.*)|((L.+|(.*)B)(.+E?)), F1 = 0.7009, Length = 0.27
# Solution 82: Regex = (L.*)|(((((((((L.+|(^M*W)|(z*)B).*))|(W)|(YE))))|(.*L))|(S.*))|(E.*)), F1 = 0.8337, Length = 0.69
# Solution 83: Regex = ((S.*)|(L.*))|((((((((L.+|(.*()E+)|L.+|(^M*W)|(.*)B).*)|(W)|(YE))))))), F1 = 0.8389, Length = 0.7
# Solution 84: Regex = (((E.*)|(L.+|(.*(()))B.*))|((S.+)))|(Ev), F1 = 0.7451, Length = 0.4
# Solution 85: Regex = ((E.*)|((L.+|(.*)B)(.+)?))|((S.*())|T(BV*)), F1 = 0.7477, Length = 0.43
# Solution 86: Regex = .*(L|(.*)(B)(.*)), F1 = 0.5536, Length = 0.17
# Solution 87: Regex = L.+|(.*())(B)(.+)?, F1 = 0.5698, Length = 0.18
# Solution 88: Regex = ((W.*)), F1 = 0.3281, Length = 0.07
# Solution 89: Regex = (B)(.+)?, F1 = 0.3414, Length = 0.08
# Solution 90: Regex = (B.*)|(W.), F1 = 0.3918, Length = 0.1
# Solution 91: Regex = ((B.*)|W.), F1 = 0.3918, Length = 0.1
# Solution 92: Regex = ((((E.*)|(L.+|(.*(()))B.*))|(S.+)))|((B.*)|(W.())), F1 = 0.7545, Length = 0.5
# Solution 93: Regex = (S.*)|(L.*), F1 = 0.4813, Length = 0.11
# Solution 94: Regex = (L+|(.*B.*)), F1 = 0.5108, Length = 0.12
# Solution 95: Regex =  ?(S.*)|(B.*), F1 = 0.5193, Length = 0.13
# Solution 96: Regex = (((((.*)\d)\s|(.*)B).*)), F1 = 0.6779, Length = 0.24
# Solution 97: Regex = E*, F1 = 0.0913, Length = 0.02
# Solution 98: Regex = (S.*)|(.*)L((L.*)|(E.))|(((((((.*(E(().*))|(((()L.+.+|(^M*W)|(.*)B).*))|(W)|(YN))))|(.*L))|(S.*)))), F1 = 0.8473, Length = 0.99
# Solution 99: Regex = B()?, F1 = 0.1495, Length = 0.04
# Solution 100: Regex = (B.*)|(W.) , F1 = 0.3562, Length = 0.11
# Generated initial population of 100 regexes.
# ==========================================================
# n_gen  |  n_eval  | n_nds  |      eps      |   indicator
# ==========================================================
#      1 |       95 |      2 |             - |             -
#      2 |      195 |      2 |  0.000000E+00 |             f
#      3 |      295 |      2 |  0.000000E+00 |             f
#      4 |      395 |      3 |  0.9954490595 |         ideal
#      5 |      495 |      3 |  0.000000E+00 |             f
#      6 |      595 |      4 |  0.1495784027 |             f
#      7 |      695 |      5 |  0.0206363861 |             f
#      8 |      795 |      5 |  0.7158563005 |         ideal
#      9 |      895 |      5 |  0.0449521138 |             f
#     10 |      995 |      6 |  0.1033946513 |         ideal
#     11 |     1095 |      7 |  0.0085155345 |             f
#     12 |     1195 |      6 |  0.0747020303 |             f
#     13 |     1295 |      6 |  0.000000E+00 |             f
#     14 |     1395 |      6 |  0.000000E+00 |             f
#     15 |     1495 |      7 |  0.0147370528 |             f
#     16 |     1595 |      7 |  0.0248447205 |             f
#     17 |     1695 |      8 |  0.1588399536 |         ideal
#     18 |     1795 |     10 |  0.000000E+00 |             f
#     19 |     1895 |     10 |  0.3531205970 |         ideal
#     20 |     1995 |      9 |  0.0128205128 |             f
#     21 |     2095 |      8 |  0.0400000000 |         nadir
#     22 |     2195 |      9 |  0.0489639420 |         ideal
#     23 |     2295 |     10 |  0.000000E+00 |             f
#     24 |     2395 |      8 |  0.0477127817 |         ideal
#     25 |     2495 |      8 |  0.000000E+00 |             f
#     26 |     2595 |      9 |  0.0161954926 |             f
#     27 |     2695 |      9 |  0.000000E+00 |             f
#     28 |     2795 |      9 |  0.000000E+00 |             f
#     29 |     2895 |     10 |  0.000000E+00 |             f
#     30 |     2995 |     11 |  0.0295087811 |             f
#     31 |     3095 |     12 |  0.000000E+00 |             f
#     32 |     3195 |     13 |  0.0047358602 |             f
#     33 |     3295 |     14 |  0.000000E+00 |             f
#     34 |     3395 |     12 |  0.0231513657 |             f
#     35 |     3495 |     12 |  0.0046392733 |             f
#     36 |     3595 |     14 |  0.0039765200 |             f
#     37 |     3695 |     14 |  0.0240376673 |             f
#     38 |     3795 |     13 |  0.0588235294 |         nadir
#     39 |     3895 |     13 |  0.000000E+00 |             f
#     40 |     3995 |     14 |  0.000000E+00 |             f
#     41 |     4095 |     14 |  0.000000E+00 |             f
#     42 |     4195 |     14 |  0.000000E+00 |             f
#     43 |     4295 |     14 |  0.0055465532 |             f
#     44 |     4395 |      9 |  0.0060309759 |             f
#     45 |     4495 |      8 |  0.0080663098 |             f
#     46 |     4595 |     10 |  0.0064530479 |             f
#     47 |     4695 |      9 |  0.3076923077 |         nadir
#     48 |     4795 |      9 |  0.000000E+00 |             f
#     49 |     4895 |      9 |  0.000000E+00 |             f
#     50 |     4995 |      9 |  0.000000E+00 |             f
#     51 |     5095 |      9 |  0.000000E+00 |             f
#     52 |     5195 |      9 |  0.0190168935 |             f
#     53 |     5295 |      7 |  0.0077541118 |             f
#     54 |     5395 |      7 |  0.000000E+00 |             f
#     55 |     5495 |      6 |  0.0090464638 |             f
#     56 |     5595 |      7 |  0.0134493350 |             f
#     57 |     5695 |      7 |  0.000000E+00 |             f
#     58 |     5795 |      7 |  0.000000E+00 |             f
#     59 |     5895 |      7 |  0.000000E+00 |             f
#     60 |     5995 |      7 |  0.000000E+00 |             f
#     61 |     6095 |      7 |  0.000000E+00 |             f
#     62 |     6195 |      9 |  0.000000E+00 |             f
#     63 |     6295 |      9 |  0.000000E+00 |             f
#     64 |     6395 |     10 |  0.000000E+00 |             f
#     65 |     6495 |     11 |  0.000000E+00 |             f
#     66 |     6595 |     12 |  0.000000E+00 |             f
#     67 |     6695 |     13 |  0.0118394029 |             f
#     68 |     6795 |     13 |  0.000000E+00 |             f
#     69 |     6895 |     13 |  0.000000E+00 |             f
#     70 |     6995 |     13 |  0.000000E+00 |             f
#     71 |     7095 |     13 |  0.000000E+00 |             f
#     72 |     7195 |     10 |  0.0833333333 |         nadir
#     73 |     7295 |      7 |  0.7142857143 |         nadir
#     74 |     7395 |      7 |  0.000000E+00 |             f
#     75 |     7495 |      7 |  0.000000E+00 |             f
#     76 |     7595 |      8 |  0.0357171013 |             f
#     77 |     7695 |      8 |  0.000000E+00 |             f
#     78 |     7795 |      8 |  0.000000E+00 |             f
#     79 |     7895 |      8 |  0.000000E+00 |             f
#     80 |     7995 |      9 |  0.0158744519 |             f
#     81 |     8095 |      9 |  0.000000E+00 |             f
#     82 |     8195 |      5 |  0.0578323871 |             f
#     83 |     8295 |      5 |  0.000000E+00 |             f
#     84 |     8395 |      5 |  0.000000E+00 |             f
#     85 |     8495 |      5 |  0.000000E+00 |             f
#     86 |     8595 |      5 |  0.000000E+00 |             f
#     87 |     8695 |      5 |  0.000000E+00 |             f
#     88 |     8795 |      5 |  0.000000E+00 |             f
#     89 |     8895 |      5 |  0.000000E+00 |             f
#     90 |     8995 |      5 |  0.000000E+00 |             f
#     91 |     9095 |      5 |  0.000000E+00 |             f
#     92 |     9195 |      5 |  0.000000E+00 |             f
#     93 |     9295 |      5 |  0.000000E+00 |             f
#     94 |     9395 |      6 |  0.000000E+00 |             f
#     95 |     9495 |      7 |  0.0594265808 |             f
#     96 |     9595 |      7 |  0.000000E+00 |             f
#     97 |     9695 |      7 |  0.000000E+00 |             f
#     98 |     9795 |      7 |  0.000000E+00 |             f
#     99 |     9895 |      7 |  0.000000E+00 |             f
#    100 |     9995 |      7 |  0.000000E+00 |             f
# Solution 1: Regex = :, F1 = 0.3318, Length = 0.01
# Solution 2: Regex = (.+ \wM), F1 = 1.5000, Length = 0.08
# Solution 3: Regex = .+(M), F1 = 1.4208, Length = 0.05
# Solution 4: Regex = (.+M)$, F1 = 1.4842, Length = 0.06
# Solution 5: Regex = M$, F1 = 0.4947, Length = 0.02
# Solution 6: Regex = (.+M$), F1 = 1.4842, Length = 0.06
# Solution 7: Regex = :.++, F1 = 0.8479, Length = 0.04
# Solution 8: Regex = P, F1 = 0.2660, Length = 0.01
# Solution 9: Regex = (().+ \wM), F1 = 1.5000, Length = 0.1
# Solution 10: Regex = .*(M), F1 = 1.3898, Length = 0.05
# Solution 11: Regex = .M, F1 = 0.4313, Length = 0.02
# Solution 12: Regex = .M$, F1 = 0.4947, Length = 0.03
# Solution 13: Regex = ..+(M), F1 = 1.4250, Length = 0.06
# Solution 14: Regex = (.*M)$+, F1 = 1.4842, Length = 0.07
# Solution 15: Regex = (.*M$+), F1 = 1.4842, Length = 0.07
# Solution 16: Regex = (.+.M), F1 = 1.4250, Length = 0.06
# Solution 17: Regex = A, F1 = 0.2550, Length = 0.01
# Solution 18: Regex = (.+( )\wM+), F1 = 1.5000, Length = 0.11
# Solution 19: Regex = :c*.+, F1 = 0.8479, Length = 0.05
# Solution 20: Regex = ::*.+, F1 = 0.8479, Length = 0.05
# Solution 21: Regex = (:.+), F1 = 0.8479, Length = 0.05
# Solution 22: Regex = M+, F1 = 0.4003, Length = 0.02
# Solution 23: Regex = (M)$, F1 = 0.4947, Length = 0.04
# Solution 24: Regex = (M$), F1 = 0.4947, Length = 0.04
# Solution 25: Regex = .M+, F1 = 0.4313, Length = 0.03
# Solution 26: Regex = ((.*M)$), F1 = 1.4842, Length = 0.08
# Solution 27: Regex = (.+(M$)), F1 = 1.4842, Length = 0.08
# Solution 28: Regex = (.+(M))$, F1 = 1.4842, Length = 0.08
# Solution 29: Regex = (.*()M)$, F1 = 1.4842, Length = 0.08
# Solution 30: Regex = ((.)+M)$, F1 = 1.4842, Length = 0.08
# Solution 31: Regex = (().+M)$, F1 = 1.4842, Length = 0.08
# Solution 32: Regex = (.+(M)$), F1 = 1.4842, Length = 0.08
# Solution 33: Regex = .+(\wM), F1 = 1.4489, Length = 0.07
# Solution 34: Regex = ((.*M))$, F1 = 1.4842, Length = 0.08
# Solution 35: Regex = ((.+M)$), F1 = 1.4842, Length = 0.08
# Solution 36: Regex = (.*(M)$), F1 = 1.4842, Length = 0.08
# Solution 37: Regex = (..*M), F1 = 1.4208, Length = 0.06
# Solution 38: Regex = 0, F1 = 0.1235, Length = 0.01
# Solution 39: Regex = .*(((:.*M+))), F1 = 1.5000, Length = 0.13
# Solution 40: Regex = (.+((:.*M+))), F1 = 1.5000, Length = 0.13
# Solution 41: Regex = (..+((:.*M))), F1 = 1.5000, Length = 0.13
# Solution 42: Regex = AM, F1 = 0.3340, Length = 0.02
# Solution 43: Regex = (.M)$, F1 = 0.4947, Length = 0.05
# Solution 44: Regex = (.M$), F1 = 0.4947, Length = 0.05
# Solution 45: Regex = (M$$), F1 = 0.4947, Length = 0.05
# Solution 46: Regex = (M)$$, F1 = 0.4947, Length = 0.05
# Solution 47: Regex = .(M)$, F1 = 0.4947, Length = 0.05
# Solution 48: Regex = (M), F1 = 0.4003, Length = 0.03
# Solution 49: Regex = ()M, F1 = 0.4003, Length = 0.03
# Solution 50: Regex = .(M), F1 = 0.4313, Length = 0.04
# Solution 51: Regex = (.M), F1 = 0.4313, Length = 0.04
# Solution 52: Regex = .(..*M), F1 = 1.4250, Length = 0.07
# Solution 53: Regex = (...*M), F1 = 1.4250, Length = 0.07
# Solution 54: Regex = (^.*()M)$, F1 = 1.4842, Length = 0.09
# Solution 55: Regex = (..*M)$(), F1 = 1.4842, Length = 0.09
# Solution 56: Regex = (.+(.M$)), F1 = 1.4842, Length = 0.09
# Solution 57: Regex = (.+(M$)$), F1 = 1.4842, Length = 0.09
# Solution 58: Regex = ((^.*)M)$, F1 = 1.4842, Length = 0.09
# Solution 59: Regex = (:.+M), F1 = 1.0162, Length = 0.06
# Solution 60: Regex = ., F1 = 0.0901, Length = 0.01
# Solution 61: Regex = ^, F1 = 0.0901, Length = 0.01
# Solution 62: Regex = $, F1 = 0.0901, Length = 0.01
# Solution 63: Regex = ((.*(:)).*)(M), F1 = 1.5000, Length = 0.14
# Solution 64: Regex = (.*(((:)).*)M), F1 = 1.5000, Length = 0.14
# Solution 65: Regex = ((.*(:)).*(M)), F1 = 1.5000, Length = 0.14
# Solution 66: Regex = (((.*:)).*)(M), F1 = 1.5000, Length = 0.14
# Solution 67: Regex = (.+((:(.)*M))), F1 = 1.5000, Length = 0.14
# Solution 68: Regex = (().+M*( \wM)), F1 = 1.5000, Length = 0.14
# Solution 69: Regex = ^.*(((:.*.M))), F1 = 1.5000, Length = 0.14
# Solution 70: Regex = ((((.* \wM)))), F1 = 1.5000, Length = 0.14
# Solution 71: Regex = ((..*(:.*.M))), F1 = 1.5000, Length = 0.14
# Solution 72: Regex = ((..+(:.*M+))), F1 = 1.5000, Length = 0.14
# Solution 73: Regex = :+, F1 = 0.3318, Length = 0.02
# Solution 74: Regex = .:, F1 = 0.3318, Length = 0.02
# Solution 75: Regex = \:, F1 = 0.3318, Length = 0.02
# Solution 76: Regex = (\wM), F1 = 0.4548, Length = 0.05
# Solution 77: Regex = A+M, F1 = 0.3340, Length = 0.03
# Solution 78: Regex = (M+), F1 = 0.4003, Length = 0.04
# Solution 79: Regex = A*+M, F1 = 0.4003, Length = 0.04
# Solution 80: Regex = (.+(M)), F1 = 1.4208, Length = 0.07
# Solution 81: Regex = .+(M()), F1 = 1.4208, Length = 0.07
# Solution 82: Regex = .(.+(M)), F1 = 1.4250, Length = 0.08
# Solution 83: Regex = (..+(M)), F1 = 1.4250, Length = 0.08
# Solution 84: Regex = (().+M)($), F1 = 1.4842, Length = 0.1
# Solution 85: Regex = ..(.+(M)), F1 = 1.4283, Length = 0.09
# Solution 86: Regex = ((.+(M$))), F1 = 1.4842, Length = 0.1
# Solution 87: Regex = (.*(()M)$), F1 = 1.4842, Length = 0.1
# Solution 88: Regex = ..(.+(M$)), F1 = 1.4842, Length = 0.1
# Solution 89: Regex = ((.*)*M$+), F1 = 1.4842, Length = 0.1
# Solution 90: Regex = 0.*(M), F1 = 0.8998, Length = 0.06
# Solution 91: Regex = (..+((:)).*(M)), F1 = 1.5000, Length = 0.15
# Solution 92: Regex = (..+((:)).*)(M), F1 = 1.5000, Length = 0.15
# Solution 93: Regex = k, F1 = 0.0000, Length = 0.01
# Solution 94: Regex = V, F1 = 0.0000, Length = 0.01
# Solution 95: Regex = (.*), F1 = 0.2704, Length = 0.04
# Solution 96: Regex = 0.*.(M), F1 = 0.9000, Length = 0.07
# Solution 97: Regex = (.+.*)(M), F1 = 1.4208, Length = 0.09
# Solution 98: Regex = (..*)(.+.M), F1 = 1.4283, Length = 0.11
# Solution 99: Regex = :J*.+$, F1 = 0.8479, Length = 0.06
# Solution 100: Regex = ($), F1 = 0.0901, Length = 0.03
#
# All evolved regex results saved to evolved_matches.txt

# %%
EVOLVED_MATCHES_FILE = 'evolved_matches.txt' 
ORIGINAL_MATCHES_FILE = 'matches.txt'

def load_json_lines_minimal(filename):
    data = []
    with open(filename, 'r', encoding='utf-8') as f:
        for line in f:
            line_content = line.strip()
            if line_content:
                try:
                    data.append(json.loads(line_content))
                except json.JSONDecodeError as e:
                    print(f"Skipping malformed JSON line in {filename}: {line_content} - Error: {e}")
    return data

def calculate_metrics_minimal(predicted_set, true_set):
    if not isinstance(predicted_set, set):
        predicted_set = set(predicted_set)
    if not isinstance(true_set, set):
        true_set = set(true_set)

    tp = len(predicted_set.intersection(true_set))
    fp = len(predicted_set.difference(true_set))
    fn = len(true_set.difference(predicted_set))

    if not true_set and not predicted_set:
        precision, recall, f1 = 1.0, 1.0, 1.0
    elif not true_set and predicted_set:
        precision, recall, f1 = 0.0, 0.0, 0.0
    elif true_set and not predicted_set:
        precision, recall, f1 = 0.0, 0.0, 0.0
    else:
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0.0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0.0
        f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0.0
    return precision, recall, f1

def plot_pareto():
    raw_evolved_data_list = load_json_lines_minimal(EVOLVED_MATCHES_FILE)
    evolved_regex_types_aggregated = {}
    for item_dict in raw_evolved_data_list:
        for name, regex_list in item_dict.items():
            if name in evolved_regex_types_aggregated:
                if isinstance(evolved_regex_types_aggregated[name], list) and isinstance(regex_list, list):
                    evolved_regex_types_aggregated[name].extend(regex_list)
                else:
                    evolved_regex_types_aggregated[name] = regex_list
            else:
                evolved_regex_types_aggregated[name] = regex_list
    original_targets_raw = load_json_lines_minimal(ORIGINAL_MATCHES_FILE)
    original_targets_map = {
        target_def['name']: {'matches_set': set(map(str, target_def['matches']))}
        for target_def in original_targets_raw if 'name' in target_def and 'matches' in target_def
    }
    all_test_strings = set()
    for target_def in original_targets_raw:
        if 'matches' in target_def:
            all_test_strings.update(map(str, target_def['matches']))
    
    valid_regex_types_to_plot = {
        name: regex_list for name, regex_list in evolved_regex_types_aggregated.items()
        if name in original_targets_map
    }
    num_types = len(valid_regex_types_to_plot)
    if num_types == 0: return
    ncols = 2 if num_types > 1 else 1
    nrows = (num_types + ncols - 1) // ncols
    fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(ncols * 7, nrows * 5.5), squeeze=False)
    axes_flat = axes.flatten()
    plot_idx = 0
    for regex_type_name, evolved_regex_list in valid_regex_types_to_plot.items():
        current_ax = axes_flat[plot_idx]
        true_set = original_targets_map[regex_type_name]['matches_set']
        all_evaluated_points_for_type = [] 
        processed_regex_strings_for_type = set()
        for evolved_regex_str in evolved_regex_list:
            if not isinstance(evolved_regex_str, str):
                print(f"Info: Non-string regex for '{regex_type_name}': {evolved_regex_str}. Skipping.")
                continue
            if evolved_regex_str in processed_regex_strings_for_type:
                continue
            processed_regex_strings_for_type.add(evolved_regex_str)
            regex_length = len(evolved_regex_str)         
            try:
                compiled_regex = re.compile(evolved_regex_str)
            except re.error as e:      
                continue 
            predicted_set = set()
            for test_str in all_test_strings:
                if not isinstance(test_str, str): continue 
                if compiled_regex.search(test_str):
                    predicted_set.add(test_str)
            
            _precision, _recall, f1 = calculate_metrics_minimal(predicted_set, true_set)
            all_evaluated_points_for_type.append((regex_length, f1))

    
        if all_evaluated_points_for_type:
            lengths = [p[0] for p in all_evaluated_points_for_type]
            f1_scores = [p[1] for p in all_evaluated_points_for_type]
            
            current_ax.scatter(lengths, f1_scores, s=30, alpha=0.6, color='mediumseagreen', label="Evolved Regex")
            
            current_ax.set_xlabel("Regex Length (lower is better)")
            current_ax.set_ylabel("F1 Score (higher is better)")
            current_ax.set_title(f"Performance: {regex_type_name}")
            current_ax.grid(True, linestyle=':', alpha=0.7)
            current_ax.set_ylim(-0.05, 1.05)
            
            min_len = min(lengths) if lengths else 0
            max_len = max(lengths) if lengths else 10
            current_ax.set_xlim(left=max(0, min_len - 5), right=max_len + 5)
            

        else: 
            current_ax.set_title(f"{regex_type_name} (No evaluable regexes)")
            current_ax.text(0.5, 0.5, "No evaluable regexes found.", 
                           horizontalalignment='center', verticalalignment='center', 
                           transform=current_ax.transAxes)
            current_ax.set_xlabel("Regex Length")
            current_ax.set_ylabel("F1 Score")
            current_ax.set_ylim(-0.05, 1.05)
            current_ax.set_xlim(0, 50) 
            current_ax.grid(True, linestyle=':', alpha=0.7)

        plot_idx += 1


    for i in range(plot_idx, len(axes_flat)):
        axes_flat[i].axis('off')

    fig.suptitle("Performance of All Evolved Regexes by Type (F1 Score vs. Length)", fontsize=16)
    plt.tight_layout(rect=[0, 0.03, 1, 0.95]) 
    plt.show()

# %%
plot_pareto()
